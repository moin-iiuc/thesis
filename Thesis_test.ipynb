# %% [markdown]
# <a href="https://colab.research.google.com/github/moin-iiuc/thesis/blob/main/Thesis_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip  install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
from numpy import *

# %%
data = pd.read_csv('Thesis/dataset.csv')

# %%
data.head()
# Out:
#                                      headline   category newspaper name
# 0    হঠাৎ করে কেঁদে ফেললেন ঐশ্বরিয়া রাই, কেন!  Amusement       Jugantor
# 1               এত দামি জুতা পরেন প্রিয়াঙ্কা!  Amusement       Jugantor
# 2             মৃত্যুর আগে শ্রীদেবীর শেষ ভিডিও  Amusement       Jugantor
# 3    কৌতুক অভিনেতা কপিল শর্মার ঘরে নতুন অতিথি  Amusement       Jugantor
# 4  বিয়ের পর কোহলির জন্য যে ত্যাগ করলেন আনুশকা  Amusement       Jugantor

# %%
data.columns
# Out:
# Index(['headline', 'category', 'newspaper name'], dtype='object')

# %%
data.shape
# Out:
# (136811, 3)

# %%
data.describe()
# Out:
#             headline       category  newspaper name
# count         136805         136811          136811
# unique        128620              6               4
# top     টিভিতে দেখুন  International  Dainik Inqilab
# freq             828          48813           83391

# %%
data.isnull().sum()
# Out:
# headline          6
# category          0
# newspaper name    0
# dtype: int64

# %%
data_part=data.dropna()

# %%
data_part.isnull().sum()
# Out:
# headline          0
# category          0
# newspaper name    0
# dtype: int64

# %%
import nltk
nltk.download('punkt')
token = nltk.word_tokenize(data_part.headline[40])
print(token)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['বলিউডে', 'আনুশকার', '১০', 'বছর']

# %%
from nltk.stem import PorterStemmer

# %%
porter = PorterStemmer()
for i in token:
  print(i,porter.stem(i))
# Out:
# বলিউডে বলিউডে
# আনুশকার আনুশকার
# ১০ ১০
# বছর বছর

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmati = WordNetLemmatizer()
for i in token:
  print(i,lemmati.lemmatize(i))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# বলিউডে বলিউডে
# আনুশকার আনুশকার
# ১০ ১০
# বছর বছর

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_word = set(stopwords.words('bengali'))
for i in token:
  if i in stop_word:
    print(i)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
pip install bltk
# Out:
# Collecting bltk
#   Downloading bltk-1.2.tar.gz (17.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sklearn>=0.0 (from bltk)
#   Downloading sklearn-0.0.post9.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from bltk) (1.16.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from bltk) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from bltk) (1.2.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from bltk) (1.23.5)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from bltk) (3.8.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from bltk) (1.3.2)
# Requirement already satisfied: certifi>=2019.11.28 in /usr/local/lib/python3.10/dist-packages (from bltk) (2023.7.22)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->bltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->bltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->bltk) (4.66.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->bltk) (3.2.0)
# Building wheels for collected packages: bltk, sklearn
#   Building wheel for bltk (setup.py) ... done
#   Created wheel for bltk: filename=bltk-1.2-py3-none-any.whl size=17432519 sha256=fcd349ff9d39bf573f381f88b12ace88d272d2dced58707d60165b2d6b74aae1
#   Stored in directory: /root/.cache/pip/wheels/52/7d/57/4806e1ef5d1ad1491ce0ac43aaa0377293efbc9a81d5b7e6c8
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post9-py3-none-any.whl size=2952 sha256=1d38db8a8e0f33a9f0f0c4368995a156602333926f597b4caeb14ebba41c67fb
#   Stored in directory: /root/.cache/pip/wheels/33/a3/d2/092b519e9522b4c91608b7dcec0dd9051fa1bff4c45f4502d1
# Successfully built bltk sklearn
# Installing collected packages: sklearn, bltk
# Successfully installed bltk-1.2 sklearn-0.0.post9

# %%
data_set = pd.read_csv('Thesis/dataset.csv')

# %%
data_set.isnull().sum()
# Out:
# headline          6
# category          0
# newspaper name    0
# dtype: int64

# %%
from bltk.langtools import Tokenizer
import csv
tokenizer = Tokenizer()
for i in range(len(pre_data.headline)):
  dt=pre_data.headline[i]
  token=tokenizer.word_tokenizer(dt)
  print(i,token)
# Out:
# Streaming output truncated to the last 5000 lines.
# 37477 ['আইপিএল', 'থেকে', 'জাতীয়', 'দলে..', '.']
# 37478 ['আনুশকার', 'মতে', 'যে', 'কারণে', 'ভালো', 'নেতা', 'হয়েছেন', 'কোহলি']
# 37479 ['তামিমের', 'পর', 'বিদায়', 'ইমরুল']
# 37480 ['শেখ', 'হাসিনা', 'স্টেডিয়াম', 'নির্মাণের', 'দরপত্রে', 'ব্যাপক', 'সাড়া']
# 37481 ['পারফরমার', 'নেই', 'পঞ্চপাণ্ডব', 'ছাড়া']
# 37482 ['বিপিএল', 'মাতাবেন', 'সালমান-ক্যাটরিনা']
# 37483 ['ক্যান্সারের', 'কাছে', 'হেরে', 'গেলেন', 'বাংলাদেশ', 'ক্রিকেটের', 'প্রথম', 'অধিনায়ক']
# 37484 ['চুক্তি', 'থেকে', 'বাদ', 'পড়ার', 'পর', 'মোসাদ্দেকের', 'সেঞ্চুরি']
# 37485 ['ক্যান্সার', 'আক্রান্ত', 'শিশুর', 'স্বপ্ন', 'পূরণ', 'করলেন', 'যুবরাজ']
# 37486 ['মেয়েকে', 'বাঁচিয়ে', 'নাগরিকত্ব', 'আইন', 'নিয়ে', 'মুখ', 'খুললেন', 'সৌরভ']
# 37487 ['দলে', 'ফিরেই', 'রেকর্ড', 'ছুঁয়ে', 'দিলেন', 'বিজয়']
# 37488 ['আইপিএলে', 'শ্লীলতাহানির', 'শিকার', 'শিক্ষিকা', '!']
# 37489 ['এক', 'ব্যাটসম্যান', 'জীবন', 'পেলেন', 'তিনবার', '!']
# 37490 ['হাসান-রাহী', 'আউট', ',', 'সৌম্য', 'হায়দার', 'ইন']
# 37491 ['বিকল্প', 'ভেন্যু', 'না', 'থাকায়', 'দিল্লিতেই', 'খেলতে', 'হচ্ছে', ':', 'পাপন']
# 37492 ['ভালো', 'শুরু', 'এনে', 'দিয়ে', 'ফিরলেন', 'ইমরুল']
# 37493 ['ড্রেসিংরুমে', 'মনোমালিন্য', 'হতেই', 'পারে', ',', 'তা', 'বাইরে', 'যাওয়া', 'ঠিক', 'নয়', ':', 'মুশফিক']
# 37494 ['পাকিস্তানের', '`সোয়েটার', "'", 'নিয়ে', 'আপত্তি', 'ওয়াসিম', 'আকরামের']
# 37495 ['কাশ্মীর', 'ভাবনায়', 'করাচির', 'কথা', 'ভুলে', 'গেছে', 'পাকিস্তান', ':', 'গম্ভীর']
# 37496 ['কোহলিকে', 'জোর', 'করে', 'চুমুর', 'চেষ্টা', ',', 'ভক্ত', 'গ্রেফতার', '!']
# 37497 ['এক', 'হৃদরোগী', 'শিশুর', 'স্বপ্নের', 'একদিন']
# 37498 ['ইন্দোরে', 'ক্রিকেটপ্রেমী', 'বীর', 'মুক্তিযোদ্ধা', 'নুর', 'বকশ']
# 37499 ['জয়', 'থেকে', '৯৮', 'রান', 'দূরে', 'বাংলাদেশ']
# 37500 ['ব্র্যাডম্যানকে', 'ছাড়িয়ে', 'নতুন', 'উচ্চতায়', 'আগারওয়াল']
# 37501 ['ভারতের', 'বিপক্ষে', 'ব্যাটিংয়ে', 'বাংলাদেশ']
# 37502 ['ওয়েস্ট', 'ইন্ডিজের', 'বিরুদ্ধে', 'টেস্ট', 'দল', 'ঘোষণা']
# 37503 ['দেশে', 'না', 'ফিরে', 'পাকিস্তানে', 'তামিম-মাহমুদউল্লাহ']
# 37504 ['‘গেইল’', 'হতে', 'পারেননি', 'মিলার']
# 37505 ['এশিয়া', 'কাপের', 'সেরা', 'ব্যাটসম্যান', 'হতে', 'পারেন', 'তামিম']
# 37506 ['ম্যাচ', 'ফিক্সিং', 'প্রতিরোধে', 'গাভাস্কারের', 'টিপস']
# 37507 ['আবু', 'হায়দার', 'রনিকে', 'আইসিসির', 'জরিমানা']
# 37508 ['বৃষ্টির', 'কারণে', 'প্রস্তুতির', 'সুযোগ', 'নষ্ট']
# 37509 ['খেলা', 'ছেড়ে', 'দিচ্ছেন', 'ইরফান', 'পাঠান', '!']
# 37510 ['যে', 'কারণে', 'এত', 'ভয়ঙ্কর', 'বুমরাহ', ',', 'জানালেন', 'ইরফান']
# 37511 ['রাজ্জাক-সাব্বিরকে', 'নিয়ে', 'ফিল্ডিংয়ে', 'বাংলাদেশ']
# 37512 ['গম্ভীরের', 'বিরুদ্ধে', 'গ্রেফতারি', 'পরোয়ানা']
# 37513 ['৯', 'রানেই', 'গুটিয়ে', 'গেল', 'মিয়ানমার']
# 37514 ['শ্রীদেবীর', 'মৃত্যুতে', 'পাক-ভারত', 'ক্রিকেটারদের', 'শোক']
# 37515 ['লিড', 'বাড়াচ্ছে', 'ইংল্যান্ড']
# 37516 ['কামরান', 'আকমলের', 'অনন্য', 'রেকর্ড']
# 37517 ['দাপুটে', 'জয়ে', 'সিরিজ', 'নিশ্চিত', 'করল', 'ভারত']
# 37518 ['বিপিএলে', 'দল', 'না', 'পেয়ে', 'আমি', 'হতাশ', 'নই', ':', 'শাহরিয়ার', 'নাফীস']
# 37519 ['বিপজ্জনক', 'জুটি', 'ভাঙলেন', 'সৌম্য']
# 37520 ['অস্ট্রেলিয়ার', 'মাঠে', 'আসাদ', 'শফিকের', 'ব্যাক', 'টু', 'ব্যাক', 'সেঞ্চুরি']
# 37521 ['সাকিব', 'নিজেও', 'খেলতে', 'চাচ্ছেন..', '.']
# 37522 ['মাশরাফির', 'জয়', 'এবং', 'খেলোয়াড়দের', 'ভোট-আনন্দ']
# 37523 ['‘আমরা', 'খেলোয়াড়রা', 'জাতীয়', 'সংগীত', 'শুনতে', 'পাচ্ছিলাম', 'না’']
# 37524 ['সালমাদের', 'সামনে', 'শিরোপা', 'জয়ের', 'হাতছানি']
# 37525 ['রাবাদা', 'নিষিদ্ধ', 'দুই', 'টেস্টে']
# 37526 ['পাকিস্তানের', 'বোলিং', 'কোচ', 'হওয়ার', 'দৌড়ে', 'এগিয়ে', 'ওয়াকার']
# 37527 ['আইরিশদের', 'কাঁদিয়ে', 'বিশ্বকাপের', 'চূড়ান্ত', 'পর্বে', 'আফগানিস্তান']
# 37528 ['মাহমুদউল্লাহদের', 'বুদ্ধিদীপ্ত', 'বোলিংয়ে', '১৯০', 'রানে', 'থামল', 'উইন্ডিজ']
# 37529 ['রশিদ', 'খানের', 'সাফল্যের', 'মূলে', 'ওয়ার্ন-মুরালিধরন']
# 37530 ['হাথুরুসিংহে-চান্দিমাল', 'নিষিদ্ধ']
# 37531 ['জীবনের', 'শেষ', 'ইনিংসে', 'ফিফটির', 'পথে', 'কুক']
# 37532 ['সরফরাজদের', 'মানসিকতার', 'উন্নতি', 'দরকার', ':', 'মিঁয়াদাদ']
# 37533 ['ওয়েস্ট', 'ইন্ডিজের', 'বিপক্ষে', 'রেকর্ড', 'সংগ্রহ', 'বাংলাদেশের']
# 37534 ['কেকেআরের', 'দায়িত্বে', 'আসছে', 'নারী', 'কোচ', '!']
# 37535 ['ঢাকা', 'টেস্টের', 'আগে', 'মুশফিককে', 'নিয়ে', 'দুঃসংবাদ', '!']
# 37536 ['মাঠে', 'ভারত', 'মাঠের', 'বাইরে', 'শ্রীলংকা', '!']
# 37537 ['শাহীন', 'আলমের', 'সাত', 'উইকেট']
# 37538 ['বিপিএলে', 'রাজশাহীর', 'অধিনায়ক', 'শোয়েব', 'মালিক']
# 37539 ['ধোনিকেও', 'ছাড়িয়ে', 'গেলেন', 'কোহলি']
# 37540 ['সাকিবের', 'এমন', '‘আবদারে’', 'বিরক্ত', 'বিসিবি']
# 37541 ['ব্রাভোর', '৩৬', 'বলে', '৯৪*']
# 37542 ['ভারতীয়', 'কোচ', 'নির্বাচক', 'কমিটি', 'বেআইনি', ':', 'সঞ্জীব', 'গুপ্ত']
# 37543 ['কলকাতার', 'জয়ে', 'উচ্ছ্বসিত', 'শাহরুখের', 'বিনিদ্র', 'রজনী']
# 37544 ['ফ্লোরিডায়', 'সাকিবরা']
# 37545 ['রশিদ-সাকিব', 'নৈপুণ্যে', 'হায়দরাবাদের', 'স্মরণীয়', 'জয়']
# 37546 ['৬', 'জুন', ':', 'আজকের', 'খেলা']
# 37547 ['আবারও', 'শচীনকে', 'ছাড়িয়ে', 'গেলেন', 'কোহলি']
# 37548 ['সিলেট', 'থেকে', 'নড়াইল', ',', 'রোড', 'টু', 'ইলেকশন']
# 37549 ['এশিয়া', 'কাপে', 'খেলা', 'না', 'খেলার', 'সিদ্ধান্ত', 'সাকিবের', ':', 'মাশরাফি']
# 37550 ['মাথায়', 'বলের', 'আঘাতে', 'দৃষ্টিপ্রতিবন্ধী', 'ক্রিকেটারের', 'মৃত্যু']
# 37551 ['জোড়ায়', 'জোড়ায়', 'সাজঘরে']
# 37552 ['সেপ্টেম্বরে', '১০০', 'বলের', 'ক্রিকেট', 'টুর্নামেন্ট']
# 37553 ['বিদায়ী', 'ম্যাচে', 'মাসাকাদজার', 'অনন্য', 'রেকর্ড']
# 37554 ['রাহুলের', 'ব্যাটে', 'পাঞ্জাবের', 'জয়']
# 37555 ['ক্রিকেটার', 'ও', 'চিয়ার', 'লিডারদের', 'সম্পর্ক', 'কী', '?']
# 37556 ['গণধর্ষিতার', 'বিরোধিতা', 'করে', 'সমালোচনায়', 'সানিয়া']
# 37557 ['নড়াইলে', 'মাশরাফি', ',', 'সাতক্ষীরায়', 'মুস্তাফিজের', 'ঈদ', 'উদযাপন']
# 37558 ['চাকরি', 'খোয়ালেন', 'পাকিস্তানের', 'কোচিং', 'স্টাফরা']
# 37559 ['সিপিএলে', 'প্রথম', 'ম্যাচেই', 'চমক', 'দেখালেন', 'সাকিব']
# 37560 ['বিপুল', 'আর্থিক', 'ক্ষতির', 'সম্মুখীন', 'সাকিব']
# 37561 ['১', 'রানে', '৩', 'উইকেট', 'হারিয়ে', 'চাপে', 'বাংলাদেশ']
# 37562 ['পাকিস্তানে', 'শুধু', 'টি-টোয়েন্টি', 'সিরিজ', 'খেলতে', 'চায়', 'বাংলাদেশ']
# 37563 ['আফগানিস্তান', 'বলেই', 'কোহলির', '‘না’']
# 37564 ['‘কোহলি', 'দেখিয়ে', 'দেবে', 'কেন', 'সে', 'সেরা’']
# 37565 ['আন্দোলনের', 'পর', 'জাতীয়', 'লিগে', 'ক্রিকেটারদের', 'ম্যাচ', 'ফি', 'বাড়ল', 'দ্বিগুণ']
# 37566 ['এরপরও', 'কি', 'বলবেন', 'এটাই', 'ভারতের', 'সেরা', 'দল', '?']
# 37567 ['ম্যাচ', 'ফিক্সিংয়ে', 'সতর্ক', 'শ্রীলংকা']
# 37568 ['শেষ', 'বলে', 'মুশফিককে', 'স্মরণ', 'করেন', 'স্টোকস']
# 37569 ['বাতিল', 'হয়নি', 'টস']
# 37570 ['হারের', 'মুখে', 'বাংলাদেশ']
# 37571 ['অভিষেকেই', 'ফিফটি', 'সাদমানের']
# 37572 ['কোহলি', 'ক্রিকেটের', '‘ডোনাল্ড', 'ট্রাম্প’', '!']
# 37573 ['ভারতের', 'অস্ট্রেলিয়া', 'জয়ের', 'সুবর্ণ', 'সুযোগ']
# 37574 ['কখনও', 'এভাবে', 'কাঁদতে', 'দেখা', 'যায়নি', 'ওয়ার্নারকে']
# 37575 ['প্রবাসি', 'বাঙালিদের', 'জন্য', 'খেলবেন', 'টাইগাররা']
# 37576 ['২৩', 'মে', ':', 'আজকের', 'খেলা']
# 37577 ['জাদরানের', 'ব্যাটিং', 'তাণ্ডবে', 'আফগানদের', 'রানের', 'পাহাড়']
# 37578 ['হতাশ', 'করলেন', 'ফজলে', 'রাব্বি']
# 37579 ['রুদ্ধশ্বাস', 'প্রতিযোগিতায়', 'হার']
# 37580 ['রুপাতেই', 'সন্তুষ্ট', 'বাকী']
# 37581 ['খেলার', 'সুযোগ', 'না', 'পেয়ে', 'পাকিস্তানি', 'ক্রিকেটারের', 'আত্মহত্যা']
# 37582 ['লাদাখে', 'সেনার', 'বেশে', 'স্বাধীনতা', 'দিবস', 'উদযাপন', 'ধোনির']
# 37583 ['আইপিএলের', 'ফাইনালের', 'ম্যান', 'অব', 'দ্য', 'ম্যাচ']
# 37584 ['প্রধানমন্ত্রীর', 'জন্মদিনে', 'ফেসবুকে', 'যা', 'লিখলেন', 'ক্রিকেটার', 'রুবেল']
# 37585 ['অ্যান্ডারসন', 'আমাদের', 'সম্পদ', ':', 'জো', 'রুট']
# 37586 ['টি-টোয়েন্টিতে', 'শ্রীলংকার', 'চেয়ে', 'পাকিস্তান', 'ভালো', 'দল', ':', 'সরফরাজ']
# 37587 ['ম্যাচ', 'বয়কটের', 'সিদ্ধান্ত', 'নিয়েছিলেন', 'সাকিব', ',', 'কেন', '?']
# 37588 ['ক্রিকেটাররা', 'আবারও', 'মনোবিদের', 'পাঠশালায়']
# 37589 ['আইপিএলে', 'মধ্যবর্তী', 'দলবদল', 'অযৌক্তিক', '!']
# 37590 ['সামি-হাসিন', 'সংঘাতের', 'আসল', 'রহস্য', 'ফাঁস', '!']
# 37591 ['মুম্বাই', 'একাদশে', 'ফিরছেন', 'মোস্তাফিজ', '!']
# 37592 ['আশার', 'বাণী', 'শোনালেন', 'মোস্তাফিজ']
# 37593 ['দক্ষিণ', 'আফ্রিকাকে', 'হারিয়ে', 'ভারতের', 'বিশ্বরেকর্ড']
# 37594 ['ডি', 'ভিলিয়ার্সের', 'কাছ', 'থেকে', 'শিখেছি', ':', 'বিরাট']
# 37595 ['অবসর', 'নিয়ে', 'যা', 'বললেন', 'ইমরান', 'তাহির']
# 37596 ['সৌম্যর', 'পর', 'বিদায়', 'তামিম', 'বিপদে', 'বাংলাদেশ']
# 37597 ['ভারতের', 'আজ', 'পাকিস্তান', 'যুদ্ধের', 'প্রস্তুতি']
# 37598 ['টাইগারদের', 'নিয়ে', 'আমি', 'গর্বিত', ':', 'স্টিভ', 'রোডস']
# 37599 ['শূন্য', 'বলে', 'শূন্য', 'রানে', 'আউট', '!']
# 37600 ['আফগানদের', 'বিপক্ষে', 'আল-আমিনের', 'চমক']
# 37601 ['ওয়ানডেতে', 'অবস্থান', 'আরও', 'সুসংহত', 'হল', 'মাশরাফিদের']
# 37602 ['আলহামদুলিল্লাহ', ',', 'আরও', 'বড়', 'গেম', 'আসছে', 'ইনশাআল্লাহ', ':', 'মুশফিক']
# 37603 ['বিরাটের', 'ছাপিয়ে', 'যাওয়ার', 'তৃষ্ণায়', 'মুগ্ধ', 'কার্স্টেন']
# 37604 ['ক্রিকেট', 'কোনো', 'খেলা', 'নয়', ':', 'রাশিয়া']
# 37605 ['আইপে', 'দিচ্ছে', 'মাঠে', 'গিয়ে', 'খেলা', 'দেখার', 'সুযোগ']
# 37606 ['শাইনপুকুরে', 'মাশরাফি', ',', 'মোহামেডানে', 'সাকিব']
# 37607 ['শচীনকে', 'আবারও', 'ছাড়িয়ে', 'গেলেন', 'কোহলি']
# 37608 ['আবারও', 'ইনিংস', 'পরাজয়ের', 'শঙ্কায়', 'পাকিস্তান']
# 37609 ['বিসিবি', 'পরিচালক', 'মাহবুবুলের', 'বিদেশযাত্রায়', 'নিষেধাজ্ঞা']
# 37610 ['পরাজয়ের', 'শঙ্কায়', 'টাইগাররা']
# 37611 ['সাকিব', 'প্রসঙ্গে', 'ঝুঁকি', 'নিতে', 'চান', 'না', 'পাপন']
# 37612 ['‘ইয়েস', 'মাই', 'লাভ’']
# 37613 ['জিম্বাবুয়ে', 'টেস্ট', 'দলে', 'এমপফু']
# 37614 ['ভয়ডরহীন', 'ক্রিকেট', 'শেখাচ্ছেন', 'গিবস']
# 37615 ['সেঞ্চুরিয়ান', 'টেস্টে', 'ছয়জন', 'ব্যাটসম্যান', 'খেলানোর', 'পক্ষে', 'সহবাগ']
# 37616 ['জম্মু-কাশ্মীরের', 'পাশে', 'রয়েছি', ',', 'পাঠানদের', 'আশ্বাস', 'সৌরভের']
# 37617 ['জাতীয়', 'দলের', 'ফিল্ডিং', 'পরামর্শক', 'রায়ান', 'কুক']
# 37618 ['বিজেপিতে', 'যোগ', 'দিচ্ছেন', 'সৌরভ', 'গাঙ্গুলি', '?']
# 37619 ['ইনজামামকে', 'ছাড়িয়ে', 'যাওয়ার', 'পথে', 'কোহলি']
# 37620 ['সম্পূর্ণ', 'ফিট', 'না', 'হয়ে', 'খেলতে', 'চাই', 'না', ':', 'সাকিব']
# 37621 ['আইপিএলে', 'সাকিবদের', 'সহকারী', 'কোচ', 'হাডিন']
# 37622 ['কোহলিদের', 'কোচ', 'হতে', 'আগ্রহী', 'জয়াবর্ধনে']
# 37623 ['আন্তর্জাতিক', 'ক্রিকেটে', 'আবারও', 'ম্যাচ', 'ফিক্সিং']
# 37624 ['এশিয়া', 'কাপ', 'কাঁপাবে', 'ফখর', 'জামান', ':', 'আমির', 'সোহেল']
# 37625 ['জাতীয়', 'নির্বাচন', 'পেছালেও', 'পেছাবে', 'না', 'বিপিএল', ':', 'পাপন']
# 37626 ['মোসাদ্দেক', 'ইস্যুতে', 'বিসিবির', 'বক্তব্য']
# 37627 ['উদ্বোধনী', 'জুটি', 'ভাঙলেন', 'সাকিব']
# 37628 ['‘ওহ', 'নো', ',', 'আল্লাহ', 'তার', 'আত্মার', 'শান্তি', 'দিন’']
# 37629 ['পাকিস্তান', 'ক্রিকেট', 'বোর্ড', 'আমার', 'কদর', 'বোঝেনি', '', ':', 'সাকলাইন', 'মুশতাক']
# 37630 ['কাশ্মীর', 'ভাগ', 'হলেও', 'ক্রিকেট', 'বোর্ড', 'একই', 'থাকছে']
# 37631 ['প্রস্তুতি', 'ম্যাচে', 'অধিনায়ক', 'মাশরাফি']
# 37632 ['নিজের', 'মৃত্যুর', 'খবরকে', 'জোকস', 'বললেন', 'ক্রিকেটার', 'শোয়েব', 'আখতার']
# 37633 ['সাকিবকে', 'ফাঁসানো', 'জুয়াড়ি', 'আগারওয়াল', 'এখন', 'কোথায়', '', '?']
# 37634 ['বাংলাদেশ-শ্রীলংকা', 'ম্যাচ', 'দিয়ে', 'আজ', 'শুরু', 'এশিয়া', 'কাপ']
# 37635 ['ক্ষুব্ধ', 'ও', 'মর্মাহত', 'সাকিব', 'ভক্তরা']
# 37636 ['লড়াই', 'করেও', 'পরাজয়', 'এড়াতে', 'পারেনি', 'ভারত']
# 37637 ['ক্যালিসের', 'এভাবে', 'দাড়ি', 'কাটার', 'রহস্য', 'কী', '?']
# 37638 ['হারলেই', 'হাথুরুর', 'শ্রীলংকার', 'বিদায়', '!']
# 37639 ['এক', 'টেস্ট', 'খেলেই', 'বিশ্বসেরা', 'নাঈম', 'হাসান']
# 37640 ['তাইজুলের', '৫', 'উইকেট', ',', 'জয়ের', 'দোরগোড়ায়', 'বাংলাদেশ']
# 37641 ['অস্ট্রেলিয়াকে', 'গুঁড়িয়ে', 'পাকিস্তানের', 'জয়']
# 37642 ['সৌম্যের', 'সেঞ্চুরিতে', 'উড়ে', 'গেল', 'জিম্বাবুয়ে']
# 37643 ['কোথায়', 'বাংলাদেশ', 'আর', 'কোথায়', 'জিম্বাবুয়ে']
# 37644 ['‘খেলা', 'না', 'পারলেও', 'বেতন', 'দেব?’']
# 37645 ['আইপিএলে', 'কেন', 'নেই', 'মুশফিক', ',', 'প্রশ্ন', 'ক্রিকেট', 'বিশ্লেষকের']
# 37646 ['অনুশীলনে', 'ফিরলেন', 'তামিম']
# 37647 ['১০', 'উইকেটে', 'জিতলেন', 'বাংলাদেশের', 'নারীরা']
# 37648 ['পাকিস্তানে', 'পৌঁছেছেন', 'সালমারা']
# 37649 ['বাংলাদেশ', 'ইমার্জিং', 'দল', 'ফাইনালে']
# 37650 ['ফেসবুক', 'লাইভে', 'এসে', 'নাসিরকে', 'নিয়ে', 'একি', 'বললেন', 'তরুণী', '!']
# 37651 ['বিসিবি', 'সভাপতির', 'পদত্যাগ', 'চাইলেন', 'শোয়েব', 'আখতার']
# 37652 ['বাংলাদেশের', 'ওয়েস্ট', 'ইন্ডিজ', 'সফরসূচি', 'চূড়ান্ত']
# 37653 ['ভারতের', 'মাঠে', 'হিতমার-শাই', 'হোপের', 'ব্যাটিং', 'তাণ্ডব']
# 37654 ['বাংলাদেশ', "'অর্ডিনারি", "'", 'দল', ':', 'গাভাস্কার']
# 37655 ['খেলা', 'শুরু', '১১টা', '৫০', 'মিনিটে']
# 37656 ['না', 'ফেরার', 'দেশে', 'ক্রিকেটার', 'মুলভ', 'জাদেজা']
# 37657 ['জরিমানা', 'দিয়ে', 'কলকাতা', 'থেকে', 'দেশে', 'ফিরলেন', 'সাইফ']
# 37658 ['বিপিএলে', 'নাসিরের', "'লজ্জার", "'", 'রেকর্ড']
# 37659 ['আইপিএল', 'নিলামে', '১০', 'কোটিতে', 'কোহলির', 'দলে', 'ক্রিস', 'মরিস']
# 37660 ['মার্শ', 'ভাইদের', 'ব্যাটে', 'বড়', 'লিডের', 'পথে', 'অস্ট্রেলিয়া']
# 37661 ['ডারবানে', 'জিতে', 'এগিয়ে', 'গেল', 'অস্ট্রেলিয়া']
# 37662 ['ছয়', 'আন্তর্জাতিক', 'ম্যাচে', 'নিষিদ্ধ', 'গুনাথিলাকা']
# 37663 ['‘সেঞ্চুরি’র', 'আগে', 'মিরপুরের', 'ওয়ানডেনামা']
# 37664 ['ভারতের', 'পরাজয়ের', 'ম্যাচে', 'কোহলির', 'রেকর্ড']
# 37665 ['ভারতকে', 'চেপে', 'ধরেছে', 'বাংলাদেশ']
# 37666 ['ধোনিকে', 'রানআউট', 'করার', 'আগে', 'যা', 'ভেবেছিলেন', 'গাপটিল']
# 37667 ['সাকিবের', 'প্রত্যাবর্তন', 'ম্যাচে', 'উইন্ডিজের', 'জন্য', 'স্পিন-ফাঁদ']
# 37668 ['মাশরাফিদের', 'জয়ে', 'রাষ্ট্রপতি-প্রধানমন্ত্রীর', 'অভিনন্দন']
# 37669 ['আইপিএলে', 'শীর্ষ', '৫', 'বোলার']
# 37670 ['চোট', 'গুরুতর', 'নয়', ',', 'ভক্তদের', 'উদ্দেশে', 'কোহলি']
# 37671 ['আফগানদের', 'কাছে', 'বাংলাদেশ', 'কেন', 'বিবর্ণ', '?']
# 37672 ['জয়ের', 'আশা', 'জাগিয়ে', 'ছিলেন', 'মুস্তাফিজ']
# 37673 ['এই', 'জয়', 'আমাদের', 'আত্মবিশ্বাস', 'আরও', 'বাড়িয়ে', 'দিয়েছে', ':', 'সাকিব']
# 37674 ['১৫', 'জুনের', 'মধ্যে', 'কোচ', 'পাচ্ছেন', 'সাকিব-তামিমরা']
# 37675 ['ব্যাটিং', 'বিপর্যয়ে', 'কলকাতা']
# 37676 ['টেইলর-মুরের', 'ফিফটিতে', 'এগোচ্ছে', 'জিম্বাবুয়ে']
# 37677 ['দুবাইয়ে', 'খেলার', 'অনুমতি', 'পাননি', 'সাকিব']
# 37678 ['ভক্তের', 'আঘাতে', 'কান', 'ভাঙল', 'বিরাট', 'কোহলির', '!']
# 37679 ['টি-টোয়েন্টি', 'সিরিজে', 'খেলছেন', 'না', 'সাকিব']
# 37680 ['অধিনায়ক', 'হবেন', 'কিনা', 'প্রশ্নে', 'যা', 'বললেন', 'মাহমুদউল্লাহ']
# 37681 ['সাকিব', 'হতে', 'না', 'পারলেও', 'কাছাকাছি', 'যেতে', 'পারব', ':', 'তাইজুল']
# 37682 ['আইসিসি-বিসিসিআই', 'দ্বন্দ্ব', 'চরমে', ',', '২৭০০', 'কোটি', 'টাকা', 'চাইলেন', 'সৌরভ']
# 37683 ['জিম্বাবুয়েকে', '২১৭', 'রানের', 'টার্গেট', 'ম্যাশ', 'বাহিনীর']
# 37684 ['চাপ', "'", 'নিচ্ছে', 'না', 'বাংলাদেশ', "'"]
# 37685 ['কোহলিকে', 'নিয়ে', '‘বাজে’', 'মন্তব্যের', 'ব্যাখ্যা', 'দিলেন', 'কামিন্স']
# 37686 ['ইমরান', 'ও', 'অ্যালান', 'বোর্ডারের', 'পাশে', 'রশিদ', 'খান']
# 37687 ['৯', 'বছর', 'পর', 'জিতল', 'বাংলাদেশ', '!']
# 37688 ['বাংলাদেশ-আফগানিস্তান', 'সিরিজে', 'সেরা', 'যারা']
# 37689 ['ক্রিকেট', 'ইতিহাসে', 'প্রথমবার', 'টি-টোয়েন্টি', 'বিশ্বকাপ', 'খেলবে', 'নামিবিয়া']
# 37690 ['ভারত', 'নয়', ',', 'এশিয়া', 'কাপ', 'হবে', 'আরব', 'আমিরাতে']
# 37691 ['ছেলেকে', 'ক্রিকেটার', 'বানাতে', 'বাড়ি', 'বিক্রি', 'করে', 'দিচ্ছেন', 'বাবা']
# 37692 ['মোস্তাফিজের', 'মুম্বাইয়ের', 'শেষ', 'সুযোগ']
# 37693 ['রাজকীয়', 'ডাবল', 'সেঞ্চুরি', ',', 'তবু', 'আইপিএলে', 'খেলবেন', 'না', 'রুট']
# 37694 ['টপ', 'অর্ডারের', 'ব্যর্থতায়', 'বিপর্যয়ে', 'বাংলাদেশ']
# 37695 ['পাকিস্তানে', 'টেস্ট', 'খেলতে', 'যাচ্ছে', 'শ্রীলংকা', '!']
# 37696 ['মুশফিকের', 'বিধ্বংসী', 'ব্যাটিংয়ে', 'বাংলাদেশের', 'সংগ্রহ', '২৬১']
# 37697 ['তামিম-বিজয়ে', 'ফিফটি']
# 37698 ['বাংলাদেশ', 'দল', 'পরিবর্তনের', 'মধ্য', 'দিয়ে', 'যাচ্ছে', ':', 'সাকিব']
# 37699 ['সাকিব', 'হয়তো', 'ভুল', 'করেছে', ',', 'অপরাধ', 'করেনি', ':', 'মাহমুদউল্লাহ']
# 37700 ['লংকান', 'শিবিরে', 'প্রথম', 'আঘাত', 'শফিউলের']
# 37701 ['ক্যান্সারের', 'সঙ্গে', 'যুদ্ধ', 'করে', 'হার', 'মানলেন', 'ইংল্যান্ড', 'অধিনায়ক']
# 37702 ['তবু', 'স্বপ্ন', 'দেখতে', 'ভয়', 'মালিঙ্গার']
# 37703 ['ওয়ানডে', 'ক্রিকেটে', 'সর্বকালের', 'সেরা', 'অধিনায়ক', 'একাদশ']
# 37704 ['যমুনা', 'ফিউচার', 'পার্কে', 'বিশ্বকাপ', 'ট্রফি']
# 37705 ['প্রধান', 'কোচের', 'এক', 'মাসের', 'বেতন', '৫দিনেই', 'পাবেন', 'বোলিং', 'কোচ']
# 37706 ['সুপার', 'ওভারের', 'আগে', 'আর্চারকে', 'কী', '‘মন্ত্র’', 'দিয়েছিলেন', 'স্টোকস']
# 37707 ['মাশরাফির', 'জন্মদিনে', 'নড়াইলে', 'বিভিন্ন', 'কর্মসূচি']
# 37708 ['দুই', 'বলের', 'ব্যবধানে', 'সাজঘরে', 'লিটন-সৌম্য']
# 37709 ['আফগান', 'পরিবারের', 'সঙ্গে', 'ক্রিকেট', 'খেলে', 'প্রশংসা', 'কুড়াচ্ছেন', 'মরগ্যান']
# 37710 ['মুশফিককে', 'ধন্যবাদ', 'জানাল', 'ভারতীয়', 'মিডিয়া']
# 37711 ['চার', 'বল', 'খেলেই', 'সাজঘরে', 'লিটন']
# 37712 ['নতুন', 'জার্সিতে', 'প্রস্তুতি', 'শুরু', 'মোস্তাফিজদের']
# 37713 ['ডিকভেলাকে', 'ফিরিয়ে', 'প্রতিরোধ', 'ভাঙলেন', 'তাইজুল']
# 37714 ['শুধু', 'একজনের', 'জন্য', 'হেরেছি', 'মনে', 'করি', 'না', ':', 'মুশফিক']
# 37715 ['আমার', "দু'টি", 'হৃদয়', ',', 'একটি', 'তুরস্ক', 'অন্যটি', 'জার্মানি', ':', 'ওজিল']
# 37716 ['হংকংকে', 'উড়িয়ে', 'পাকিস্তানের', '৮', 'উইকেটে', 'জয়']
# 37717 ['ভারত-বাংলাদেশ', 'ম্যাচ', 'বাতিলের', 'পক্ষে', 'গম্ভীর', '!']
# 37718 ['হঠাৎ', 'হাসপাতালে', 'তামিম']
# 37719 ['কিংবদন্তি', 'শচীনের', 'সঙ্গে', 'কাটার', 'মাস্টার', 'মোস্তাফিজ']
# 37720 ['আন্তর্জাতিক', 'ক্রিকেট', 'থেকে', 'অবসর', 'নিলেন', 'অ্যালিস্টার', 'কুক']
# 37721 ['শোয়েব', 'মালিক', 'তাহলে', 'আউট']
# 37722 ['সাকিবের', 'চেয়ে', 'মোস্তাফিজের', 'দাম', 'বেশি']
# 37723 ['টস', 'জিতে', 'বোলিংয়ে', 'কলকাতা']
# 37724 ['ক্যালিস', 'মুখ', 'খুললেন']
# 37725 ['বুমরাহর', 'মুখোমুখি', 'হতে', 'চান', 'না', 'কোহলি']
# 37726 ['জয়ের', 'পথে', 'ভারত']
# 37727 ['ধোনি', 'একাই', '৮০০', '!']
# 37728 ['মার্টিন', 'ক্রো-টেইলরকে', 'টপকে', 'শীর্ষে', 'উইলিয়ামসন']
# 37729 ['মঈনকে', '‘ওসামা’', 'বলে', 'ডেকেছিল', 'এক', 'অস্ট্রেলীয়', 'ক্রিকেটার']
# 37730 ['আমাকে', 'খেলানোর', 'জন্য', 'হায়দরাবাদকে', 'ধন্যবাদ', ':', 'সাকিব']
# 37731 ['পাকিস্তানের', 'বিপক্ষে', 'গুনাথিলাকার', 'সেঞ্চুরি']
# 37732 ['ড্রেসিংরুমে', 'আসলে', 'তেমন', 'কিছুই', 'হয়নি', ':', 'মাহমুদউল্লাহ']
# 37733 ['ফুটবল', 'খেলেও', 'দর্শক', 'মাতালেন', 'মাশরাফি']
# 37734 ['টাইগারদের', 'পারফরম্যান্সে', 'হতাশ', 'পাপন', 'যা', 'বললেন']
# 37735 ['ভারতে', 'বিতর্কিত', 'আইন', 'নিয়ে', 'বিক্ষোভ', ',', 'সরলো', 'রঞ্জি', 'ট্রফির', 'ম্যাচ']
# 37736 ['চেন্নাইয়ের', 'বিপক্ষে', 'হায়দরাবাদের', 'চ্যালেঞ্জিং', 'স্কোর']
# 37737 ['কোহলিনামা']
# 37738 ['মারাত্মক', 'অভিযোগ']
# 37739 ['যে', 'কারণে', 'এতটা', 'বিপর্যয়ে', 'পড়তে', 'হলো']
# 37740 ['নিমিষেই', 'শেষ', 'ভারতের', 'ইতিহাস', 'গড়ার', 'স্বপ্ন']
# 37741 ['কোচের', 'ব্যাপারে', 'হাল', 'ছেড়ে', 'দিয়েছে', 'বিসিবি', '!']
# 37742 ['রাজনীতিতেও', 'ইমরানকে', 'অধিনায়ক', 'হিসেবে', 'দেখতে', 'চান', 'কপিলরা']
# 37743 ['২৮', 'ডিসেম্বর', ':', 'আজকের', 'খেলা']
# 37744 ['জয়ের', 'পথে', 'বাংলাদেশ', ',', 'সাজঘরে', 'সাকিব']
# 37745 ['পাকিস্তান', 'সফরের', 'আগেই', 'বোলিং', 'কোচ', 'নিয়োগের', 'চেষ্টা', 'করছি', ':', 'আকরাম', 'খান']
# 37746 ['কলকাতার', 'প্রধান', 'কোচ', 'হলেন', 'ম্যাককালাম']
# 37747 ['আফগানদের', 'কাছ', 'থেকে', 'তেমন', 'কিছু', 'শেখার', 'নেই', ':', 'মাহমুদউল্লাহ']
# 37748 ['আল্লামা', 'ইকবাল', '‘দিবস’', 'পালনের', 'দাবি', 'আফ্রিদির']
# 37749 ['বুমরাহর', 'বোলিং', 'অ্যাকশন', 'ত্রুটিপূর্ণ', ':', 'কপিল']
# 37750 ['সিলেটকে', 'শিরোপা', 'উপহার', 'দিতে', 'চান', 'ওয়াকার']
# 37751 ['ব্রাদার্সকে', 'খেলা', 'দেখালো', 'খেলাঘর']
# 37752 ['খেলোয়াড়দের', 'বয়স', '‘চুরির’', 'সুযোগ', 'আর', 'থাকছে', 'না']
# 37753 ['হ্যারিকেন্সকে', 'হারিয়ে', 'বিগ', 'ব্যাশ', 'চ্যাম্পিয়ন', 'অ্যাডিলেড']
# 37754 ['লড়াকু', 'ইনিংসের', 'পর', 'সাজঘরে', 'শোয়েব']
# 37755 ['বিপিএলে', 'আবারও', 'ঢাকার', 'অধিনায়ক', 'মাশরাফি']
# 37756 ['বিপিএলে', 'চট্টগ্রামে', 'খেলবেন', 'গেইল']
# 37757 ['তামিম-লিটন-সৌম্যকে', 'হারিয়ে', 'চাপে', 'বাংলাদেশ']
# 37758 ['‘এখন', 'আমরা', 'সিদ্ধান্তও', 'নিতে', 'পারি’']
# 37759 ['সিলেট', 'সিক্সার্সে', 'ইমরান', 'তাহির']
# 37760 ['সাজঘরে', 'লিটনও']
# 37761 ['টি-টোয়েন্টিতে', 'আফ্রিকার', 'ইতিহাসে', 'সর্বনিম্ন', 'স্কোর']
# 37762 ['মিরপুরে', 'সালমান-ক্যাটরিনার', 'নাচ', 'ভিআইপিদের', 'জন্য', '!']
# 37763 ['কোহলির', 'বিরাট', 'অধপতন']
# 37764 ['এক', 'বছর', 'কঠিন', 'সময়', 'পার', 'করতে', 'হবে', '', ':', 'বিসিবি']
# 37765 ['পাকিস্তানকে', 'হারিয়ে', 'ইতিহাস', 'গড়তে', 'চায়', 'আয়ারল্যান্ড']
# 37766 ['ছাঁটাই', 'হচ্ছেন', ',', 'জানেন', 'না', 'হাথুরুসিংহে', '!']
# 37767 ['ওয়ার্নারই', 'আমাকে', 'বল', 'বিকৃতি', 'করতে', 'বলেছে', ':', 'ব্যানক্রফট']
# 37768 ['তামিমদের', 'সঙ্গে', 'যোগ', 'দিলেন', 'রুবেল', ',', 'রইল', 'বাকি', '৪']
# 37769 ['সেঞ্চুরি', 'ছাড়াই', 'রানের', 'পাহাড়', 'গড়ল', 'পূর্বাঞ্চল']
# 37770 ['মিকি', 'আর্থারের', 'সমান', 'বেতন', 'চান', 'মিসবাহ']
# 37771 ['সিনেমায়', 'অভিনয়', 'করছেন', 'হরভজনও']
# 37772 ['আগের', 'ম্যাচের', 'জয়ের', 'নায়ক', 'ডুপ্লেসিসের', 'বিদায়']
# 37773 ['উড়ন্ত', 'সূচনার', 'পর', 'চাপে', 'সিলেট']
# 37774 ['ডোপ', 'টেস্টে', 'নিষিদ্ধ', 'ভারতীয়', 'ওপেনার']
# 37775 ['আইসিসি', 'থেকে', '৮৬', 'কোটি', 'টাকা', 'পাচ্ছে', 'পাকিস্তান']
# 37776 ['বিকালে', 'আইপিএল', 'নিলাম', ',', 'দল', 'পেতে', 'পারেন', 'মুশফিক']
# 37777 ['আমার', 'মন-প্রাণ', 'এখনও', 'কাশ্মীরে', 'পড়ে', 'আছে', ':', 'ইরফান', 'পাঠান']
# 37778 ['২৯', 'ডিসেম্বর', ':', 'আজকের', 'খেলা']
# 37779 ['ইনজুরি', 'কাটিয়ে', 'ফিরছেন', 'তামিম']
# 37780 ['পঞ্চাশ', 'রানের', 'জুটি', 'গড়ে', 'সাজঘরে', 'মাশরাফি-মিরাজ']
# 37781 ['১২', 'হাজারি', 'গেইল']
# 37782 ['রোহিত', 'ও', 'অশ্বিনবিহীন', 'ভারত', 'অপরিবর্তিত', 'অস্ট্রেলিয়া']
# 37783 ['চট্টগ্রামের', 'উইকেট', 'নিয়ে', 'আইসিসির', '‘অসন্তুষ্টি’']
# 37784 ['রোহিত', 'ঝড়ে', 'মুম্বাইয়ের', 'রানের', 'পাহাড়']
# 37785 ['ভারত-বাংলাদেশ', 'টেস্ট', ':', 'জিলাপি', 'মুখে', 'লক্ষ্মণ-গম্ভীরের', 'ছবি', 'ভাইরাল']
# 37786 ['মিরপুরে', 'মুশফিকের', 'মহাকাব্য']
# 37787 ['ভুল', 'বোঝাবুঝির', 'শিকার', 'মাহমুদউল্লাহ']
# 37788 ['সোবার্সও', 'মানতে', 'পারছেন', 'না']
# 37789 ['ভারতে', 'যদি', 'কোনো', 'দল', 'ওদের', 'হারাতে', 'পারে', ',', 'সেটা', 'বাংলাদেশ', ':', 'পাপন']
# 37790 ['ভালো', 'প্রস্তুতির', 'স্বস্তি']
# 37791 ['শাস্তি', 'কমানোর', 'আবেদন', 'করবেন', 'না', 'স্মিথ']
# 37792 ['ফ্র্যাঞ্চাইজিরা', 'আগ্রহী', 'নয়', 'বিপিএলের', 'স্পন্সর', 'হতে']
# 37793 ['কঠিন', 'পরীক্ষার', 'সামনে', 'ইংল্যান্ড', 'ক্রিকেট', 'দল']
# 37794 ['শুরুর', 'ধাক্কা', 'সামলে', 'আড়াইশ’', 'পার', 'ইংল্যান্ডের']
# 37795 ['‘দেয়ালে', 'পিঠ', 'ঠেকে', 'গেছে’']
# 37796 ['শিখর', 'ধাওয়ানের', '২৬তম', 'ফিফটি']
# 37797 ['১৪', 'বছর', 'পর', 'জ্যামাইকায়', 'বাংলাদেশ']
# 37798 ['ইডেন', 'টেস্ট', ':', 'ধূসর', 'ব্যাটিংয়ে', 'উধাও', 'গোলাপি', 'সুরভি']
# 37799 ['ওয়েস্ট', 'ইন্ডিজকে', '১৮৫', 'রানের', 'টার্গেট', 'বাংলাদেশের']
# 37800 ['দল', 'ও', 'মুশফিকের', 'প্রশংসায়', 'মাশরাফি']
# 37801 ['পিসিবির', 'ক্রিকেট', 'কমিটিতে', 'ওয়াসিম', 'আকরাম', 'ও', 'মিসবাহ']
# 37802 ['সাকিব', 'ফের', 'বীরবেশে', 'ফিরবে', ',', 'বিশ্বাস', '১৪', 'দলের']
# 37803 ['কোহলিকে', 'থামানোর', 'নীলনকশা', 'পন্টিংয়ের']
# 37804 ['কোহলিকে', 'নিয়ে', 'যে', 'আফসোস', 'আনুশকার']
# 37805 ['চলছে', 'লুইস-রোহিতের', 'ব্যাটিং', 'ঝড়']
# 37806 ['বোল্ড', 'হয়ে', 'সাজঘরে', '৫', 'ব্যাটসম্যান', ',', 'বিপর্যয়ে', 'উইন্ডিজ']
# 37807 ['সাকিব-মুশফিকের', 'ব্যাটে', 'ছুটছে', 'বাংলাদেশ']
# 37808 ['একজন', 'রিকশাচালকও', 'আমাদের', 'প্রেরণা', ':', 'মুশফিক']
# 37809 ['মোস্তাফিজে', 'মুগ্ধ', 'রোহিত']
# 37810 ['মুশফিককে', 'নিয়ে', 'সংশয়', ',', 'দলে', 'লিটন']
# 37811 ['কোহলি-রোহিতদের', 'হত্যার', 'হুমকি']
# 37812 ['সাকিবের', 'পাশেই', 'থাকবে', 'বাংলাদেশ']
# 37813 ['দুঃসময়ে', 'পাকিস্তানকে', 'পাশে', 'পাচ্ছে', 'ভারত']
# 37814 ['৩', 'বছরের', 'জেল', 'হতে', 'পারে', 'শামির']
# 37815 ['বিপজ্জনক', 'জুটি', 'ভাঙলেন', 'মিরাজ']
# 37816 ['ফিরলেন', 'মুমিনুল', ',', 'চাপে', 'বাংলাদেশ']
# 37817 ['ভারতকে', 'হারানোর', 'ম্যাচে', 'বমি', 'করেন', '২', 'বাংলাদেশি', 'ক্রিকেটার']
# 37818 ['নিষিদ্ধ', 'স্মিথের', 'অবদান', 'বার্বাডোজের', 'জয়ে']
# 37819 ['বজ্রপাতে', 'ভারতীয়', 'ক্রিকেটারের', 'মৃত্যু']
# 37820 ['মুশফিকের', 'ভরসায়', 'বাংলাদেশ']
# 37821 ['আমাদের', 'জন্য', 'এটা', '‘ওয়েক', 'আপ', 'কল’', ':', 'পাকিস্তান', 'অধিনায়ক']
# 37822 ['আইপিএলের', 'নিলামে', 'হাজারো', 'ক্রিকেটার']
# 37823 ['বিপিএল', 'নিলামে', 'দেশি', 'ক্রিকেটাররা', 'কে', 'কোন', 'ক্যাটাগরিতে', ',', 'ভিত্তিমূল্য', 'কত', '?']
# 37824 ['বাংলাদেশের', 'বিপক্ষেও', 'নেই', 'বুমরাহ', '!']
# 37825 ['কোহলিকে', 'ছাড়িয়ে', 'গেলেন', 'মুমিনুল']
# 37826 ['সিপিএলে', 'মাঠে', 'নেমেই', 'জয়', 'পেলেন', 'মাহমুদউল্লাহ', 'রিয়াদ']
# 37827 ['সন্তানের', 'নাম', 'রাখলেন', 'ইমরুল', 'ও', 'তাসকিন']
# 37828 ['ছেলেকে', 'ঘাম', 'ঝরানোর', 'পরামর্শ', 'দিলেন', 'শচীন']
# 37829 ['এবার', 'রুবেলের', 'ছোবল', ',', 'বিপর্যয়ে', 'ওয়েস্ট', 'ইন্ডিজ']
# 37830 ['তামিমের', '২৫তম', 'ফিফটি']
# 37831 ['আইপিএলে', 'খেলবেন', 'শচীনপুত্র', '!']
# 37832 ['‘বাংলাদেশ', 'সুবিধা', 'পাবে', 'এমন', 'উইকেটও', 'আশা', 'করছি', 'মিরপুরে’']
# 37833 ['‘মিরপুরে', 'পছন্দের', 'উইকেট', 'পাওয়া', 'অসম্ভব’']
# 37834 ['এক', 'ম্যাচে', 'যত', 'রেকর্ড', 'রোহিতের']
# 37835 ['হেরেও', 'শীর্ষে', 'সাকিবদের', 'হায়দরাবাদ']
# 37836 ['জয়', 'দিয়ে', 'বছর', 'শুরু', 'করতে', 'চায়', 'মাশরাফিরা']
# 37837 ['বাংলাদেশকেই', 'এগিয়ে', 'রাখছেন', ':', 'আবু', 'জায়েদ']
# 37838 ['সাকিব', "'ভাগ্যে", "'", 'শিরোপা', 'জিতবে', 'বার্বাডোজ', '!']
# 37839 ['নাসিরের', 'আউটে', 'চাপে', 'বাংলাদেশ']
# 37840 ['এমন', 'জয়ে', 'ডিগবাজি', 'না', 'দিয়ে', 'উপায়', 'আছে', '?']
# 37841 ['ঢাকা', 'থেকে', 'বরিশাল', 'আশরাফুলের', 'ইচ্ছা', 'পূরণ']
# 37842 ['জয়', 'দিয়ে', 'সিরিজ', 'শেষ', 'শ্রীলংকার']
# 37843 ['টস', 'জিতে', 'ব্যাটিংয়ে', 'আফগানিস্তান']
# 37844 ['পাকিস্তানে', 'পিএসএল', 'খেলতে', 'চান', 'না', 'বিদেশি', 'ক্রিকেটাররা']
# 37845 ['পাওয়েল-রাসেল', 'ঝড়ে', 'উড়ে', 'গেলেন', 'আফ্রিদি']
# 37846 ['বাংলাদেশের', 'বিপক্ষে', 'টস', 'করলেই', 'বিশ্বরেকর্ড', 'রশিদের']
# 37847 ['‘তিনজনকে’', 'মিস', 'করবেন', '‘চাপমুক্ত’', 'মুমিনুল']
# 37848 ['টি', '২০', 'সিরিজ', 'জয়', 'হবে', 'নতুন', 'বছরের', 'উপহার']
# 37849 ['লিটনকে', 'নিয়ে', 'সুখবর', 'মিলেছে']
# 37850 ['যে', 'কারণে', 'কেসরিক', 'উইলিয়ামসের', 'নকল', 'করলেন', 'কোহলি', '(ভিডিও', ')']
# 37851 ['প্রথমবার', 'পাঁচ', 'উইকেট', 'পেয়ে', 'ভালো', 'লাগছে', ':', 'সাকিব']
# 37852 ['বাংলাদেশের', 'বিপক্ষে', 'সম্ভাব্য', 'পাকিস্তান', 'একাদশ']
# 37853 ['ভারতের', 'গতিতে', 'বিধ্বস্ত', 'ইংল্যান্ড']
# 37854 ['‘তাহলে', 'ওয়েস্ট', 'ইন্ডিজ', 'থেকে', 'বোলার', 'আনতে', 'হবে’']
# 37855 ['ক্রসফায়ারের', 'পক্ষে', 'গম্ভীরের', 'যুক্তি', '!']
# 37856 ['টেস্টে', 'বাংলাদেশের', 'হয়ে', 'সর্বোচ্চ', 'উইকেট', 'নেয়া', 'চার', 'বোলার']
# 37857 ['বউ', 'নিয়ে', 'বোর্ডের', 'কাছে', 'একি', 'আবেদন', 'কোহলির', '!']
# 37858 ['হংকংকে', 'উড়িয়ে', 'দিয়েছে', 'শ্রীলংকা']
# 37859 ['গেইলের', 'সেঞ্চুরি', 'পাঞ্জাবের', 'সংগ্রহ', '১৯৩']
# 37860 ['মোস্তাফিজের', 'জাদুকরী', 'শেষ', 'ওভার']
# 37861 ['পাকিস্তান', 'দলে', 'স্পিন', 'কোচ', 'প্রয়োজন', ':', 'ইয়াসির', 'শাহ']
# 37862 ['বয়স', 'কোনো', 'বিষয়', 'নয়', ',', 'ফিটনেসই', 'আসল']
# 37863 ['বাংলাদেশের', 'ইনিংস', 'যেন', '‘একতলা’', 'বাড়ি']
# 37864 ['স্যামুয়েলসকে', 'ফেরালেন', 'রুবেল', ',', 'কোণঠাসা', 'উইন্ডিজ']
# 37865 ['টেস্ট-ওয়ানডে', 'নয়', ',', 'বাংলাদেশের', 'সঙ্গে', 'টি-টোয়েন্টি', 'চায়', 'অস্ট্রেলিয়া', '!']
# 37866 ['এক', 'ম্যাচ', 'হাতে', 'রেখেই', 'সিরিজ', 'জয়', 'পাকিস্তানের']
# 37867 ['ভারতের', 'উদ্বোধনী', 'জুটি', 'ভাঙলেন', 'সাকিব']
# 37868 ['উইন্ডিজের', 'বিপক্ষে', 'রোহিত', 'শর্মার', 'ব্যাটিং', 'তাণ্ডব']
# 37869 ['এক', 'উইকেটের', 'মূল্য', '৩০', 'লাখ', 'টাকা', '!']
# 37870 ['সাকিবের', 'দ্বিতীয়', 'শিকার', 'আসগর']
# 37871 ['ইমরুলের', 'তৃতীয়', 'ওয়ানডে', 'সেঞ্চুরি']
# 37872 ['অবশেষে', 'সাফল্যের', 'কারণ', 'জানালেন', 'হাথুরুসিংহে']
# 37873 ['দারুণ', 'সূচনা', 'জিম্বাবুয়ের']
# 37874 ['কোহলি-রোহিতের', 'সঙ্গে', 'পাল্লা', 'দিলেন', 'বাবর', 'আজম']
# 37875 ['তামিমের', 'ঝড়ো', 'সেঞ্চুরি', ',', 'জয়ের', 'পথে', 'বাংলাদেশ']
# 37876 ['যে', 'কৌশলে', 'বারবার', 'হেটমায়ারকে', 'আউট', 'করেন', 'মিরাজ']
# 37877 ['লংকানদের', '‘আত্মবিশ্বাস’', 'হেরাথ']
# 37878 ['স্মিথের', 'ডাবল', 'সেঞ্চুরিতে', 'অস্ট্রেলিয়ার', 'রানের', 'পাহাড়']
# 37879 ['দুবাইয়ে', 'রেকর্ডের', '‘রাজা’', 'ইয়াসির', 'শাহ']
# 37880 ['বরফে', 'ক্রিকেট', 'ঝড়', 'উঠাবেন', 'আফ্রিদি-শেবাগরা']
# 37881 ['গুলশানে', 'সাকিব-তামিমদের', '১৩', 'দফা', 'দাবিতে', 'সংবাদ', 'সম্মেলন']
# 37882 ['টসে', 'আন্দ্রে', 'রাসেলকে', 'হারালেন', 'মুশফিক']
# 37883 ['আইপিএলে', 'ধোনির', 'দলে', 'খেলবেন', 'লিটন', '!']
# 37884 ['নিজে', 'হাঁটতে', 'পারছেন', 'না', 'জয়সুরিয়া']
# 37885 ['সেই', 'স্টোকসের', 'অবিশ্বাস্য', 'ইনিংসে', 'ইংলিশদের', 'শ্বাসরুদ্ধকর', 'জয়']
# 37886 ['মালিককে', 'ফিরিয়ে', 'পথের', 'কাঁটা', 'সরালেন', 'রুবেল']
# 37887 ['আয়ারল্যান্ড-বাংলাদেশ', 'ওয়ানডে', 'সিরিজের', 'সূচি', 'প্রকাশ']
# 37888 ['পাকিস্তানের', 'বোলিং', 'নিয়ে', 'কঠোর', 'সমালোচনা', 'শোয়েব', 'আখতারের']
# 37889 ['অ্যালেনকে', 'ফেরালেন', 'সাকিব', ',', 'ধ্বংসস্তূপে', 'ওয়েস্ট', 'ইন্ডিজ']
# 37890 ['ধোনিকে', 'নেতা', 'হিসেবে', 'পেতে', 'মরিয়া', 'ছিলেন', 'টেন্ডুলকার']
# 37891 ['অবশেষে', 'উইকেট', 'পেলেন', 'মালিঙ্গা']
# 37892 ['পাকিস্তানে', 'এসেই', 'ক্রিকেট', 'খেলতে', 'হবে', ':', 'এহসান', 'মানি']
# 37893 ['‘সাকিব', 'না', 'থাকলে', 'অনেক', 'সমস্যা', 'হয়’']
# 37894 ['‘খেলাধুলা', 'মাদক', 'থেকে', 'দূরে', 'রাখে’']
# 37895 ["'দাদাগিরিতে", "'", 'ভূতের', 'আবির্ভাব', ',', 'আদালতে', 'বিজ্ঞানকর্মীরা']
# 37896 ['শ্রীলংকার', 'বিপক্ষে', 'পাকিস্তানের', 'দল', 'ঘোষণা']
# 37897 ['১১৭', 'পেরোতেই', 'কাঁপাকাঁপি', 'দক্ষিণ', 'আফ্রিকার']
# 37898 ['সাকিবের', 'হায়দরাবাদ-শাহরুখের', 'কলকাতা', '‘সেমিফাইনাল’', 'আজ']
# 37899 ['সাকিবকে', 'ছাড়িয়ে', '‘বিশ্বসেরা’', 'হওয়ার', 'পথে', 'তাইজুল', '!']
# 37900 ['ক্যারিয়ারের', 'প্রথম', 'ফিফটি', 'লিটনের']
# 37901 ['যুব', 'বিশ্বকাপে', 'বাংলাদেশের', 'প্রতিপক্ষ', 'ভারত']
# 37902 ['মুশফিককে', 'নিয়ে', 'দুশ্চিন্তা', 'নেই', ',', 'আঙুল', 'ভেঙে', 'গেলেও', 'খেলবেন', '!']
# 37903 ['ভারতকে', 'অ্যান্ডারসনের', 'ছোবল']
# 37904 ['মাহমুদউল্লাহ-সানজামুলে', '৫০০', 'ছোঁয়ার', 'পথে', 'বাংলাদেশ']
# 37905 ['চাইলেই', 'দলে', 'ফেরা', 'যাবে', 'না', 'বললেন', 'আশরাফুল']
# 37906 ['অদম্য', 'অনন্য', 'আফগানিস্তান']
# 37907 ['ব্যাটে-বলে', 'উজ্জ্বল', 'সাকিব', ',', 'সেন্ট', 'লুসিয়াকে', 'উড়িয়ে', 'প্লেঅফে', 'বার্বাডোজ']
# 37908 ['আইপিএলে', 'অন্য', 'এক', 'রাহুল']
# 37909 ['ভারতীয়রা', 'চায়', 'মুশফিক', 'আইপিএল', 'নিলামে', 'থাকুক']
# 37910 ['ওয়ানডেতে', '২', 'অধিনায়কের', 'গোল্ডেন', 'ডাক', 'প্রথম', 'দেখল', 'বিশ্ব']
# 37911 ['ক্রিকেটকে', 'বিদায়', 'বললেন', 'রঙ্গনা', 'হেরাথ']
# 37912 ['জিম', 'করে', '১০', 'কেজি', 'ওজন', 'কমালেন', 'মাশরাফি']
# 37913 ['রেকর্ড', 'তো', 'ভাঙার', 'জন্যই', ',', 'প্রতিদ্বন্দ্বিতা', 'হওয়া', 'উচিত', ':', 'সাকিব']
# 37914 ['টেস্টে', 'প্রথম', '‘এক', 'হাজারি’', 'ইংল্যান্ড']
# 37915 ['ঘন', 'ঘন', 'ভারত-পাকিস্তান', 'লড়াই', 'দেখতে', 'চান', 'আফ্রিদি']
# 37916 ['মুশফিকের', 'ব্যাটিংয়ে', 'মুগ্ধ', 'হরভজন']
# 37917 ['সুযোগ', 'কাজে', 'লাগাতে', 'পারলেন', 'না', 'মুশফিক']
# 37918 ['স্ত্রীর', 'কারণে', 'যুক্তরাষ্ট্রের', 'ভিসা', 'পেতে', 'সামির', 'ঝামেলা']
# 37919 ['কোহলিদের', 'এই', 'জয়', 'অর্থহীন', '!']
# 37920 ['আগুন', 'ঝরাচ্ছেন', 'মাশরাফি', ',', 'ধুঁকছে', 'ওয়েস্ট', 'ইন্ডিজ']
# 37921 ['রিটায়ার্ড', 'হার্ট', 'লিটন', ',', 'নিয়ম', 'থাকলেও', 'বদলি', 'নেয়ার', 'উপায়', 'নেই', '!']
# 37922 ['শ্রীলংকায়', '৩০০', 'রান', 'করলেও', 'জেতা', 'সম্ভব', 'না', ':', 'তামিম']
# 37923 ['ক্রিকেটের', 'চেয়ে', 'জীবন', 'অনেক', 'বড়']
# 37924 ['মাশরাফির', 'জন্য', 'ভোট', 'চাইতে', 'নড়াইল', 'এসেছি', ':', 'ছাত্রলীগ', 'সভাপতি']
# 37925 ['হাসপাতাল', 'থেকে', 'বাসায়', 'ফিরেছেন', 'সাকিব']
# 37926 ['বাংলাদেশকে', '১৭৭', 'রানের', 'টার্গেট', 'দিল', 'ভারত']
# 37927 ['মুমিনুল', 'ও', 'সৌম্যকে', 'নিয়ে', 'সালাহউদ্দিন']
# 37928 ['বিশ্ব', 'একাদশের', 'হয়ে', 'খেলবেন', 'না', 'সাকিব']
# 37929 ['এভাবে', 'জিততে', 'চাননি', 'মরগ্যান']
# 37930 ['র\u200c্যাংকিংয়ে', 'তামিম-সাকিবের', 'উন্নতি']
# 37931 ['বাংলাদেশকে', 'শতভাগ', 'সহযোগিতা', 'করব', ':', 'সৌরভ', 'গাঙ্গুলী']
# 37932 ['বিরাটের', 'সঙ্গ', 'দারুণ', 'উপভোগ', 'করছেন', 'আনুশকা']
# 37933 ['আফগানিস্তানের', 'সঙ্গে', 'পরাজয়ের', 'চার', 'কারণ']
# 37934 ['ক্রিকেটারের', 'স্ত্রীকে', 'শ্লীলতাহানির', 'অভিযোগ', 'সঙ্গীতশিল্পীর', 'বাবার', 'বিরুদ্ধে']
# 37935 ['আমার', 'টাকাটা', 'দিয়ে', 'দেন', ',', 'পাপনকে', 'সাকিব']
# 37936 ['মুরকে', 'ফিরিয়ে', 'ভয়ংকর', 'জুটি', 'ভাঙলেন', 'মিরাজ']
# 37937 ['প্রথম', 'বলেই', 'সাজঘরে', 'লিটন']
# 37938 ['কানাডায়', 'টি', '২০', 'খেলবেন', 'স্মিথ']
# 37939 ['উদ্বোধনী', 'ম্যাচে', 'অভিষেক', 'হচ্ছে', 'মিশুর']
# 37940 ['দুপুরে', 'শিরোপা', 'লড়াইয়ে', 'মাঠে', 'নামবেন', 'সালমারা']
# 37941 ['সাকিবের', "'নিষেধাজ্ঞা", "'", 'সম্পর্কে', 'কিছুই', 'জানেন', 'না', 'পাপন']
# 37942 ['অস্ট্রেলিয়াকে', 'হারিয়ে', '‘বিস্কুট’', 'জিতে', 'নিল', 'পাকিস্তান']
# 37943 ['হারলে', 'পৃথিবী', 'শেষ', 'হয়ে', 'যেত', 'বাটলারের']
# 37944 ['বিরাটকে', 'নিয়ে', 'বিস্ফোরক', 'মন্তব্য', 'রাজ্জাকের']
# 37945 ['ভালো', 'খেলার', 'প্রত্যাশা', 'সালমাদের']
# 37946 ['ওয়াটসনের', 'আরও', 'একটি', 'সেঞ্চুরি']
# 37947 ['ভারতই', "'", 'চাপে', 'থাকবে', "'"]
# 37948 ['এশিয়া', 'কাপ', 'ফাইনালে', 'তীরে', 'গিয়ে', 'তরী', 'ডুবল', 'বাংলাদেশের']
# 37949 ['স্টাম্প', 'ভেঙে', 'ফেললেন', 'মোহাম্মদ', 'সামি']
# 37950 ['ভারতের', 'মাঠে', 'উইন্ডিজের', 'রানের', 'পাহাড়']
# 37951 ['প্রথম', 'শ্রেণির', 'ক্রিকেটে', 'লিটনের', 'দ্রুততম', 'ডাবল', 'সেঞ্চুরি']
# 37952 ['শানাকা', 'ঝড়ে', 'বাংলাদেশকে', 'বড়', 'টার্গেট', 'দিল', 'শ্রীলংকা']
# 37953 ['এশিয়া', 'কাপ', 'থেকে', 'শ্রীলংকার', 'বিদায়']
# 37954 ['মেয়েদের', 'হোম', 'সিরিজ', 'পাকিস্তানের', 'সঙ্গে', '!']
# 37955 ['স্মিথ-ওয়ার্নার-ব্যানক্রফটকে', 'দেশে', 'পাঠানো', 'হচ্ছে']
# 37956 ['পাকিস্তানে', 'খেলতে', 'আসছে', 'ওয়েস্ট', 'ইন্ডিজ', ':', 'পিসিবি', 'চেয়ারম্যান']
# 37957 ['আশা', 'জাগিয়েও', 'হারল', 'বাংলাদেশ']
# 37958 ['আমরা', 'সবাই', 'ওকে', 'জড়িয়ে', 'ধরব', ':', 'মাহমুদউল্লাহ']
# 37959 ['বিজ্ঞানী', 'হওয়ার', 'স্বপ্ন', 'নিয়ে', 'ক্রিকেটার', 'হলেন', 'রুমানা']
# 37960 ['মুমিনুল-লিটনে', 'লড়াইয়ে', 'বাংলাদেশ']
# 37961 ['পরকীয়ার', 'খেসারতে', 'বোর্ডের', 'চুক্তি', 'থেকে', 'বাদ', 'সামি']
# 37962 ['ক্রিকেট', 'মাঠে', 'মর্মান্তিক', 'মৃত্যু', 'কলেজ', 'ছাত্রের']
# 37963 ['সাত', 'হারের', 'পর', 'সাত', 'রানের', 'জয়', 'অস্ট্রেলিয়ার']
# 37964 ['মনে', 'হচ্ছে', '২৫', 'বছরের', 'তরুণ', 'আমি', ':', 'গেইল']
# 37965 ['টেস্ট', 'দুর্বলতা', 'কাটাতে', 'না', 'পারলে', 'বাংলাদেশের', 'দাম', 'থাকবে', 'না']
# 37966 ['হবে', 'না', 'বিপিএল', '!']
# 37967 ['জয়ের', 'জন্য', 'আফগানদের', 'ক্ষিধে', 'খুব', 'বেশি', 'ছিল', ':', 'নাফীস']
# 37968 ['জুনিয়রদের', 'দায়িত্ব', 'নিতে', 'হবে']
# 37969 ['বোল্টের', 'হ্যাটট্রিকে', 'পাকিস্তানকে', 'উড়িয়ে', 'দিল', 'নিউজিল্যান্ড']
# 37970 ['রবি', 'শাস্ত্রীই', 'থাকছেন', 'কোহলিদের', 'কোচ', '!']
# 37971 ['বড়', 'স্কোরের', 'ভিত', 'গড়ে', 'ফিরলেন', 'সাকিব']
# 37972 ['গেইলের', 'পর', 'এবার', 'লুইসেরও', '‘না’']
# 37973 ['বলিউড', 'থেকে', 'আইপিএলে', 'এই', 'ক্রিকেটার']
# 37974 ['বাংলাদেশ', 'একাদশে', 'আসছে', 'এক', 'পরিবর্তন', '!']
# 37975 ['ফিফটি', 'করে', 'ফিরলেন', 'মিথুন', ',', 'বড়', 'লিডের', 'পথে', 'বাংলাদেশ']
# 37976 ['দারুণ', 'ইনিংস', 'খেলে', 'ফিরলেন', 'সাদমান']
# 37977 ['‘সাকিব-তামিমকে', 'ছাড়া', 'ভারতকে', 'সামলানো', 'কঠিন’']
# 37978 ['লর্ডসে', 'শেষ', 'মহারণে', 'লড়বেন', 'যারা']
# 37979 ['আইপিএলে', 'যুবরাজ', 'পাত্তাই', 'পেল', 'না']
# 37980 ['দুর্ভাগ্য', 'লিটনের', ',', 'দুর্ভাগ্য', 'বাংলাদেশের']
# 37981 ['পাকিস্তানের', 'বিপক্ষেই', 'ফিরছেন', 'স্মিথ-ওয়ার্নার', '!']
# 37982 ['কাশ্মীর', 'ইস্যুতে', 'জাতিসংঘকে', 'আফ্রিদির', 'খোঁচা']
# 37983 ['সাকিবদের', 'বিপক্ষে', 'আফগানিস্তানের', 'দল', 'ঘোষণা']
# 37984 ['সমর্থকদের', 'বিক্ষোভ', 'না', 'করার', 'অনুরোধ', 'সাকিবের']
# 37985 ['ভারত-বাংলাদেশ', 'সিরিজ', 'দেখাবে', 'যেসব', 'চ্যানেল']
# 37986 ['আইপিএলে', 'লুঙ্গির', 'দাম', '১৫', 'কোটি', 'টাকা', '!']
# 37987 ['‘বিশ্বকাপে', 'যেতে', 'হলে', 'যোগ্যতার', 'পরিচয়', 'দিতে', 'হবে’']
# 37988 ['ব্যাটে-বলে', 'দুই', 'বিরল', 'রেকর্ডে', 'ইশান্ত']
# 37989 ['শফিউলের', 'পর', 'ভারত', 'শিবিরে', 'আমিনুলের', 'আঘাত']
# 37990 ['দীপিকাকে', 'ফিরিয়ে', 'দিলেন', 'বিরাট', 'কোহলি']
# 37991 ['টি-টেনের', 'জমকালো', 'আয়োজনে', 'থাকছেন', 'শাকিব', 'খান']
# 37992 ['এবি', 'ডি', 'ভিলিয়ার্স', 'রংপুর', 'রাইডার্সে']
# 37993 ['তামিমের', 'অভাব', 'বোধ', 'করবেন', 'সাকিব']
# 37994 ['এখনও', 'প্রিমিয়ার', 'লিগের', 'পারিশ্রমিক', 'পাননি', 'কাপালিরা']
# 37995 ['সাংবাদিকের', 'ওপর', 'ক্ষেপে', 'গেলেন', 'রোহিত', '!']
# 37996 ['ক্রিকেটার-পুলিশের', 'হাবুডুবু', 'প্রেম', ',', 'চুপিসারে', 'বিয়ে']
# 37997 ['সাকিব', 'গ্রেট', 'লিডার', ',', 'তার', 'জন্য', 'দুঃখ', 'হচ্ছে', ':', 'জামাল', 'ভূঁইয়া']
# 37998 ['জিম্বাবুয়ে', 'বোলারদের', 'জবাব', 'পাচ্ছেন', 'না', 'টাইগাররা']
# 37999 ['চেন্নাইকে', 'হারিয়ে', 'দ্বিতীয়', 'জয়', 'পেল', 'মুস্তাফিজবিহীন', 'মুম্বাই']
# 38000 ['এশিয়া', 'কাপে', 'মহানুভবতা', 'দেখালেন', 'বাংলাদেশি', 'দর্শকরা']
# 38001 ['স্পেশাল', 'পুরস্কার', 'পেলেন', 'ফখর', 'জামান']
# 38002 ['২২', 'গজে', 'ক্রিকেটার', 'শোয়েব-অভিনেতা', 'জাফরের', 'তুমুল', 'লড়াই', '(ভিডিও', ')']
# 38003 ['সাকিবকে', 'নিয়ে', 'আইপিএলে', 'মাতামাতি', '!']
# 38004 ['খেলার', 'স্বার্থেই', '‘বিনোদন', 'তরুণীদের’', 'ওপর', 'নিষেধাজ্ঞা']
# 38005 ['ভুয়া', 'কোম্পানির', 'বিজ্ঞাপন', 'করে', 'বিপাকে', 'গৌতম', 'গম্ভীর']
# 38006 ['ব্যাটসম্যানদের', 'শাসনে', 'বোলাররা', 'যেন', 'প্রজা']
# 38007 ['দেশবাসীকে', 'চিন্তা', 'করতে', 'বললেন', 'মাশরাফি']
# 38008 ['বিদায়', 'মাশরাফি', ',', 'ভরসা', 'মুশফিক']
# 38009 ['অস্ট্রেলিয়ার', 'নতুন', 'অধিনায়ক', 'উসমান', 'খাজা']
# 38010 ['আফ্রিদিকে', 'শুভেচ্ছা', 'জানিয়ে', 'আইসিসির', 'টুইট']
# 38011 ['অলক', 'কাপালির', 'সঙ্গে', 'যেখানে', 'মিল', 'গুনাথিলাকার']
# 38012 ['হাথুরুর', 'পদত্যাগের', 'কারণ', 'সাকিব', 'নয়']
# 38013 ['বাংলাদেশের', '‘ফাইনাল’', 'আজ']
# 38014 ['বিপজ্জনক', 'মেন্ডিসকে', 'ফেরালেন', 'মাশরাফি']
# 38015 ['বাংলাদেশের', 'সিরিজ', 'বাতিল', ',', 'স্যোশাল', 'মিডিয়ায়', 'সমালোচনার', 'ঝড়']
# 38016 ['বাংলাদেশকে', 'স্বপ্ন', 'দেখাচ্ছেন', 'নাইম']
# 38017 ['বুলবুলকে', 'ছাড়িয়ে', 'ইতিহাস', 'গড়লেন', 'ও’ব্রায়েন']
# 38018 ['‘তুমি', 'একটি', 'বিশেষ', 'প্রতিভা', 'ছিলে’']
# 38019 ['অস্ট্রেলিয়ায়', 'বাজে', 'পারফরম্যান্সের', 'জন্য', 'তিনজনকে', 'দুষছেন', 'মিসবাহ']
# 38020 ['টস', 'জিতে', 'বোলিংয়ে', 'বাংলাদেশ']
# 38021 ['টি', '২০', 'সিরিজও', 'দ', '.', 'আফ্রিকার']
# 38022 ['প্রধানমন্ত্রীর', 'অভিনন্দন']
# 38023 ['আইপিএল', 'নিলামে', 'বাংলাদেশের', 'তিন', 'ক্রিকেটার']
# 38024 ['ওয়ানডে', 'আর', 'টি-টোয়েন্টি', 'নিয়ে', 'পড়ে', 'থাকলে', 'টেস্টে', 'উন্নতি', 'হবে', 'না', ':', 'ফারুক']
# 38025 ['দক্ষিণ', 'ভারত', 'যাওয়ার', 'চেয়ে', 'পাকিস্তান', 'যাওয়া', 'ভালো', ':', 'সিধু']
# 38026 ['হাসিন', 'আমাকে', 'মেরে', 'ফেলার', 'হুমকি', 'দিচ্ছে', ':', 'ক্রিকেটার', 'সামি']
# 38027 ['সাকিব', 'ও', 'নূরুল', 'হাসানকে', 'জরিমানা']
# 38028 ['সাকিবের', 'দুই', 'বলে', 'দুই', 'ওপেনার', 'সাজঘরে']
# 38029 ['ইয়ো', 'ইয়ো', 'পরীক্ষার', 'বিরুদ্ধে', 'শচীন']
# 38030 ['‘সাব্বির', 'বড়', 'শট', 'খেলতে', 'পারে', ',', 'সীমানা', 'ছাড়াতে', 'পারে’']
# 38031 ['ধাওয়ানের', 'সেঞ্চুরির', 'পরও', '৩০০', 'হলো', 'না', 'ভারতের']
# 38032 ['আইপিএল', '‘মৃত্যুর’', 'কারণ']
# 38033 ['পাকিস্তানিরা', '‘অন্ধ’', 'নাকি', 'আইসিসি', '!']
# 38034 ['‘বুড়ো’', 'গেইলের', 'অসাধারণ', 'ক্যাচ', '!']
# 38035 ['আন্তঃবিশ্ববিদ্যালয়', 'ক্রিকেটের', 'ফাইনালে', 'রাবি', 'ও', 'শাবি']
# 38036 ['ইডেন', 'টেস্ট', 'দেখতে', 'শেখ', 'হাসিনাকে', 'মোদির', 'চিঠি']
# 38037 ['ফের', 'ব্যর্থ', 'সৌম্য']
# 38038 ['চিকিৎসার', 'অভাবে', 'নিভে', 'যাচ্ছে', 'নারী', 'ক্রিকেটার', 'চামেলীর', 'জীবন']
# 38039 ['রুবেলের', 'প্রিয়', 'দল', 'ব্রাজিল', ',', 'আপনার', 'কোনটি', '?']
# 38040 ['আনুশকার', 'সঙ্গে', 'যেভাবে', 'সম্পর্ক', 'হয়েছিল', 'কোহলির']
# 38041 ['‘ভালো', 'খেলারও', 'লক্ষ্য', 'থাকবে’']
# 38042 ['রংপুর', 'রাইডার্স-ম্যাগনিটো’র', 'চুক্তি', 'স্বাক্ষর']
# 38043 ['সাকিবকে', 'ফুল', 'দিয়ে', 'কারাগারে', 'সেই', 'দর্শক']
# 38044 ['তামিমকে', 'ছুটি', 'দিয়ে', 'বিপাকে', 'নির্বাচকরা', '!']
# 38045 ['মোস্তাফিজের', 'প্রশংসায়', 'রোহিত']
# 38046 ['আকমলকে', 'আরও', 'একটি', 'সুযোগ', 'দিতে', 'চান', 'মিসবাহ']
# 38047 ['ফিরলেন', 'সাকিব', ',', 'বোলিংয়ে', 'বাংলাদেশ']
# 38048 ['সামিকে', 'টানা', 'তিন', 'ঘণ্টা', 'পুলিশের', 'জেরা']
# 38049 ['বিশ্বকাপে', 'যাদের', 'সমর্থক', 'মাশরাফি-সাকিবরা']
# 38050 ['বিজেপিতে', 'সৌরভের', 'যোগদানের', 'গুঞ্জন', ',', 'যা', 'বললেন', 'অমিত', 'শাহ']
# 38051 ['মাঠ', 'থেকে', 'হাসপাতালে', 'সাকিব']
# 38052 ['রবি', 'শাস্ত্রীকেই', 'কোচ', 'হিসেবে', 'রেখে', 'দিল', 'বিসিসিআই']
# 38053 ['টি', '২০', 'বিশ্বকাপের', 'নাম', 'বদল']
# 38054 ['খেললে', 'সাকিবই', 'অধিনায়ক']
# 38055 ['ম্যাচসেরা', 'মুশফিক']
# 38056 ['টেইলরের', 'লড়াকু', 'সেঞ্চুরি']
# 38057 ['একটা', 'ভালো', 'দিনের', 'অপেক্ষায়', 'মাশরাফি']
# 38058 ['এই', 'চারটা', 'দিন', 'আমার', 'ক্যারিয়ারের', 'স্মরণীয়', ':', 'কুক']
# 38059 ['নতুন', 'এই', 'জার্সি', 'পরেই', 'টেস্ট', 'খেলবেন', 'সাকিবরা']
# 38060 ['মাশরাফির', 'মতো', 'করেই', 'ভাবছেন', 'আমলা']
# 38061 ['বাংলাদেশের', 'নতুন', 'কোচ', 'রাসেল', 'ডমিঙ্গো']
# 38062 ['টি', '১০', 'লিগে', 'আট', 'দল']
# 38063 ['অধিনায়ক', 'হিসেবে', 'মাশরাফির', 'বিকল্প', 'নেই', ':', 'পাপন']
# 38064 ['বিরাটের', 'নতুন', 'ট্যাটু', 'ভাইরাল']
# 38065 ['সঙ্গিনী', 'থাকলে', 'আরও', 'ভালো', 'খেলতে', 'পারে', 'ক্রিকেটাররা', ':', 'সানিয়া']
# 38066 ['উড়ন্ত', 'সূচনা', 'রাজশাহীর']
# 38067 ['ঢাকা', 'টেস্টে', 'ফিরছেন', 'মোস্তাফিজ', '!']
# 38068 ['কোহলির', 'ব্যাটিং', 'দেখে', 'টাইগারদের', 'শেখা', 'উচিত', ':', 'লক্ষণ']
# 38069 ['মিঠুন-মুশফিকের', 'ফিফটিতে', 'বাংলাদেশের', 'জয়']
# 38070 ['‘সাকিবরা', 'না', 'চাইলে', 'আমরা', 'আর', 'হেলিকপ্টারে', 'যাব', 'না’']
# 38071 ['বোলারদের', 'কারণে', 'পাকিস্তানের', 'জরিমানা']
# 38072 ['এশিয়া', 'কাপ', 'দেখাবে', 'যেসব', 'চ্যানেল']
# 38073 ['নির্বাচকদের', 'মধুর', 'সমস্যা']
# 38074 ['ইনস্টাগ্রামে', 'প্রতি', 'পোস্টে', 'কোহলির', 'আয়', '১', 'কোটি', '৬৫', 'লাখ', 'টাকা']
# 38075 ['অপেক্ষায়', 'বাংলাদেশ', 'ভারত', 'মরিয়া']
# 38076 ['সাকিব', 'দেশে', 'ফিরছেন', 'এমন', 'সংবাদে', 'বিব্রত', 'বিসিবি']
# 38077 ['প্রথম', 'বাংলাদেশি', 'হিসেবে', 'মমিনুলের', 'রেকর্ড']
# 38078 ['পাকিস্তান', 'ক্রিকেটের', 'গডফাদার', 'মিসবাহ', ':', 'আর্থার']
# 38079 ['প্রথম', 'বলেই', 'সাজঘরে', 'ইয়াসির', 'আলী']
# 38080 ['আগে', 'দেশ', ',', 'পরে', 'ধোনি', ':', 'গম্ভীর']
# 38081 ['জিম্বাবুয়ের', 'বিপক্ষে', 'বাংলাদেশের', 'সম্ভাব্য', 'একাদশ']
# 38082 ['মোস্তাফিজের', 'দ্বিতীয়', 'শিকার', 'সরফরাজ', ',', 'চাপে', 'পাকিস্তান']
# 38083 ['ভারতের', 'বিপক্ষে', 'বাংলাদেশ', 'একাদশে', 'আসছে', 'দুই', 'পরিবর্তন', '!']
# 38084 ['সাইফের', 'পর', 'রনির', 'আঘাত', ',', 'শুরুতেই', 'চাপে', 'জিম্বাবুয়ে']
# 38085 ['টি-টোয়েন্টিতেও', 'ফিরলেন', 'স্মিথ-ওয়ার্নার']
# 38086 ['ম্যাচ', 'পাতানোর', 'সন্দেহে', 'গ্রেফতার', '৫', 'ভারতীয়']
# 38087 ['আজ', 'ফিরছেন', 'সাকিব']
# 38088 ['লাঞ্চের', 'আগে', 'ফিরলেন', 'ইমরুল']
# 38089 ['৩৫-এ', 'ফিরলেন', 'টাইবু']
# 38090 ['বাংলাদেশের', 'বিপক্ষে', 'পাকিস্তানকে', 'যেভাবে', 'খেলতে', 'বললেন', 'শোয়েব']
# 38091 ['রাজকুমারের', 'সিং', '‘হাসন’', 'জয়', '!']
# 38092 ['কোহলি-পূজারার', 'ব্যাটে', 'ভারতের', 'চওড়া', 'হাসি']
# 38093 ['ভারতীয়', 'ক্রিকেটকে', 'শাসন', 'করতে', 'চলেছেন', 'যে', '৪', 'মুখ']
# 38094 ['নাগিন', 'নাচের', 'জনক', 'যিনি']
# 38095 ['হায়দরাবাদের', 'অধিনায়ক', 'হতে', 'পারতেন', 'সাকিবও']
# 38096 ['বাবা', 'শচীনের', 'মতোই', 'অভিষেক', 'হল', 'অর্জুনের']
# 38097 ['পৃথ্বীর', 'সেঞ্চুরিতে', 'প্রথম', 'দিনে', 'ভারতের', 'সংগ্রহ', '৩৬৪']
# 38098 ['আফগানিস্তানের', 'ঐতিহাসিক', 'টেস্ট', 'হবে', 'ব্যাঙ্গালুরুতে']
# 38099 ['জিতেছে', 'পাঞ্জাব', ',', 'হারেননি', 'ধোনি', '!']
# 38100 ['সাকিবের', 'ব্যাটে', 'টাইগারদের', 'জয়']
# 38101 ['কোহলিকে', 'খেলায়', 'মন', 'দেয়ার', 'পরামর্শ', 'ভক্তদের']
# 38102 ['টি-টোয়েন্টি', 'দলের', 'অধিনায়ক', 'মাহমুদউল্লাহ']
# 38103 ['মিসবাহর', 'একসঙ্গে', 'দুই', 'দায়িত্ব', 'দুর্দান্ত', 'সিদ্ধান্ত', ':', 'সোহেল', 'তানভীর']
# 38104 ['মিরাজের', 'ব্যাটে', 'ছক্কা', ',', 'অবাক', 'কোহলি']
# 38105 ['আমাকে', 'কেন', ',', 'এই', 'প্রশ্নটি', 'নির্বাচকদের', 'করুন', ':', 'আকরাম', 'খান']
# 38106 ['ভুল', 'শুধরে', 'নতুন', 'শুরুর', 'অপেক্ষায়', 'বাংলাদেশ']
# 38107 ['ভোট', 'দিলেন', 'মাশরাফি', 'ও', 'তার', 'স্ত্রী']
# 38108 ['পাকিস্তানকে', 'লজ্জা', 'দিয়ে', 'ফাইনালে', 'ভারত']
# 38109 ['যেসব', 'জায়গায়', 'উন্নতির', 'কথা', 'বললেন', 'মাশরাফি']
# 38110 ['কোহলিকে', 'নিয়ে', 'বিস্ফোরক', 'দাবি', 'ইরফানের']
# 38111 ['লড়াইটা', 'সাকিব', 'রশিদেরও']
# 38112 ['পাকিস্তান-ভারত', '‘যুদ্ধের’', 'সব', 'টিকিট', 'বিক্রি']
# 38113 ['শঙ্কার', 'মেঘ', 'কেটে', 'গেছে', ',', 'যথাসময়ে', 'গড়াবে', 'ম্যাচ']
# 38114 ['প্রেমিকা', 'প্রমাকে', 'জীবনসঙ্গী', 'করলেন', 'ক্রিকেটার', 'রনি']
# 38115 ['তুষার', 'ইমরান', 'তাহলে', 'সুযোগ', 'পেলেন']
# 38116 ['স্বপ্ন', 'পূরণ', 'হলো', 'নেপালের']
# 38117 ['টি', '২০', 'র\u200c্যাংকিংয়ের', 'শীর্ষে', 'পাকিস্তান']
# 38118 ['বিশ্বকাপে', 'উঠে', 'বিশেষ', 'বার্তা', 'গেইলের']
# 38119 ['শচীনের', 'পাশে', 'কোহলি']
# 38120 ['সংখ্যায়', 'প্রথম', 'ওয়ানডে']
# 38121 ['বাংলাদেশের', 'লক্ষ্য', 'ধারাবাহিকতা', ',', 'ঘুরে', 'দাঁড়াতে', 'চায়', 'শ্রীলংকা']
# 38122 ['ভারতের', 'বিপক্ষে', 'গেইলের', 'ব্যাটিং', 'তাণ্ডব']
# 38123 ['আম্পায়ারকে', 'মারতে', 'ব্যাট', 'নিয়ে', 'তাড়া', 'করলেন', 'ক্রিকেটার']
# 38124 ['মুশফিকের', 'বিতর্কিত', 'আউট']
# 38125 ['পাকিস্তানের', 'টেস্ট', 'অধিনায়ক', 'হচ্ছেন', 'আজহার', 'আলী', '!']
# 38126 ['ভারত', 'সফর', 'নিয়ে', 'ষড়যন্ত্র', 'হচ্ছে', ':', 'পাপন']
# 38127 ['সেই', 'টুম্পায়', 'মজেছে', 'বাংলাদেশের', 'ক্রিকেটাররা', '(ভিডিও', ')']
# 38128 ['তামিমকে', 'পাচ্ছে', 'না', 'বাংলাদেশ', '!']
# 38129 ['টস', 'জিতে', 'ব্যাটিংয়ে', 'হংকং']
# 38130 ['ফেসবুকে', 'সাকিব', 'আল', 'হাসানের', 'নির্বাচনী', 'পোস্টার']
# 38131 ['বিশেষজ্ঞ', 'চিকিৎসকের', 'পরামর্শ', 'নিতে', 'ব্যাংককে', 'তামিম']
# 38132 ['মুশফিকের', 'দুর্দান্ত', 'ব্যাটিং']
# 38133 ['আজ', 'শুরু', 'বিসিএলের', 'তৃতীয়', 'রাউন্ড']
# 38134 ['আশরাফুলের', '‘লাকি', 'থার্টিন’']
# 38135 ['ফুটবলের', 'প্রতি', 'ছোটবেলা', 'থেকেই', 'আমার', 'দুর্বলতা', 'রয়েছে', ':', 'সাকিব']
# 38136 ['সামিকে', 'গ্রেফতারের', 'দাবি', ',', 'আদালতে', 'হাসিনের', 'জবানবন্দি']
# 38137 ['রোহিতের', 'মতো', 'বিধ্বংসী', 'ব্যাটিং', 'করতে', 'কোহলিকেও', 'দেখিনি', ':', 'শেহবাগ']
# 38138 ['টস', 'জিতে', 'ব্যাটিংয়ে', 'ইংল্যান্ড']
# 38139 ['টি-টোয়েন্টি', 'র\u200c্যাংকিয়ে', 'বোলিং', 'শীর্ষে', 'রশিদ', 'খান', ',', 'সেরা', 'দশে', 'মোস্তাফিজ']
# 38140 ['কেমন', 'হবে', 'এবার', 'বাংলাদেশ', 'দল']
# 38141 ['সম্ভাব্য', 'বাংলাদেশ', 'একাদশ']
# 38142 ['নান্দনিক', 'ইনিংস', 'খেলে', 'ফিরলেন', 'মুশফিক']
# 38143 ['‘বিশ্বসেরা', 'অধিনায়ক', 'হওয়া', 'কঠিন', ',', 'এমপি', 'সাহেব’']
# 38144 ['জয়', 'দেখছে', 'ইংল্যান্ড', 'কোণঠাসা', 'শ্রীলংকা']
# 38145 ['আইপিএল', '২০২০', ':', 'যেসব', 'ক্রিকেটারদের', 'ধরে', 'রাখল', 'ফ্র্যাঞ্চাইজিগুলো']
# 38146 ['ব্যাটিং', 'বিপর্যয়ে', 'বাংলাদেশ']
# 38147 ['এবার', 'মাশরাফির', 'আঘাত', ',', 'জিম্বাবুয়ে', '৩', 'উইকেটে', '৩৪']
# 38148 ['রাজা', 'শিকার', 'মাশরাফির']
# 38149 ['সাকিবকে', '২', 'কোটি', 'রুপিতে', 'নিল', 'হায়দরাবাদ']
# 38150 ['যুক্তরাষ্ট্রে', 'গেইলদের', 'বিপক্ষে', '২টি', 'টি-টোয়েন্টি', 'খেলবেন', 'সাকিবরা']
# 38151 ['নেহরার', 'বিশ্বকাপ', 'সেরা', 'একাদশে', 'সাকিব']
# 38152 ['টালমাটাল', 'অস্ট্রেলিয়ার', 'হাল', 'ধরলেন', 'ল্যাঙ্গার']
# 38153 ['পাকিস্তানকে', '১৮৩', 'রানের', 'টার্গেট', 'দিল', 'শ্রীলংকা']
# 38154 ['মুশফিকের', 'টানা', '৪', 'চারেই', 'ম্যাচের', 'মোড়', 'ঘুরে', 'যায়', '!']
# 38155 ['ভারত', 'সফরে', 'সাকিব', 'যাবে', 'কিনা', 'মঙ্গলবার', 'জানাতে', 'পারব', ':', 'আকরাম', 'খান']
# 38156 ['‘মোস্তাফিজ', 'অভিজ্ঞ', 'সে', 'জানে', 'কখন', 'কি', 'করতে', 'হবে’']
# 38157 ['আইপিএল', 'চেয়ারম্যানকে', 'পতিতা', '‘ঘুষ’', 'ক্রিকেটারের', '!']
# 38158 ['ইনজামামের', 'ভাতিজার', 'বিশ্ব', 'রেকর্ড']
# 38159 ['শাহরুখকে', 'সতর্ক', 'করলেন', 'শচীন', '(ভিডিও', ')']
# 38160 ['হার্ট', 'অ্যাটাক', 'হয়ে', 'মাঠেই', 'ভারতীয়', 'ক্রিকেটারের', 'মৃত্যু']
# 38161 ['ইডেনে', 'আজ', 'গোলাপি', 'টেস্টে', 'ঘণ্টা', 'বাজাবেন', 'প্রধানমন্ত্রী']
# 38162 ['পোলার্ড', 'ঝড়ে', 'মুম্বাইয়ের', 'সংগ্রহ', '১৮৬']
# 38163 ['মেন্ডিসও', 'ফিরলেন']
# 38164 ['নাসিম', 'শাহর', 'বিশ্ব', 'রেকর্ড']
# 38165 ['উইকেট', 'শিকারের', 'রহস্য', 'ফাঁস', 'করলেন', 'আর্চার']
# 38166 ['ইরফান-হরভজনের', 'পর', 'বুমরাহর', 'হ্যাটট্রিক']
# 38167 ['বাংলাদেশের', 'বিপক্ষে', 'ভারতের', 'যে', 'কোনো', 'ম্যাচই', 'কঠিন', ':', 'কার্তিক']
# 38168 ['মাশরাফি', 'গেলেন', 'ওয়েস্ট', 'ইন্ডিজ']
# 38169 ['টেস্টে', 'কোন', 'দেশের', 'সর্বনিম্ন', 'রান', 'কত', '?']
# 38170 ['বিপিএলে', 'রংপুরের', 'অধিনায়ক', 'মোহাম্মদ', 'নবী']
# 38171 ['বাংলাদেশকে', 'ব্যঙ্গ', 'করে', 'স্টার', 'স্পোর্টসের', 'বিতর্কিত', 'বিজ্ঞাপন']
# 38172 ['বুম', 'বুম', 'বুমরাহতে', 'একদিন', 'আগে', 'জিতল', 'ভারত']
# 38173 ['যুক্তরাষ্ট্রে', 'টি-টোয়েন্টি', 'সিরিজ', 'খেলবে', 'বাংলাদেশ']
# 38174 ['জিততে', 'হলে', 'কী', 'করতে', 'হবে', ',', 'বললেন', 'সাকিব']
# 38175 ['কোহলি', 'ক্রিকেটের', 'সব', 'রেকর্ড', 'ভেঙে', 'দেবে', ':', 'গাভাস্কার']
# 38176 ['ইতিহাস', 'গড়ে', 'শীর্ষে', 'অ্যারন', 'ফিঞ্চ']
# 38177 ['স্টার্ককে', 'ছেড়ে', 'দিল', 'কেকেআর']
# 38178 ['ক্রিকেট', 'মাঠে', 'আবারও', 'মৃত্যু']
# 38179 ['টস', 'জিতে', 'ব্যাটিংয়ে', 'কুমিল্লা']
# 38180 ['ভারতের', 'বিপক্ষে', 'টাই', 'জয়তুল্য', ':', 'আফগান', 'অধিনায়ক']
# 38181 ['গেইলের', 'সঙ্গে', 'রোহিতের', 'মিল', 'কোথায়', ',', 'জানেন', '?']
# 38182 ['টেইলরের', 'একার', 'লড়াই', 'সিরিজ', 'সমতা', 'নিউজিল্যান্ডের']
# 38183 ['বাংলাদেশের', 'জয়', 'শততম', 'টেস্টে']
# 38184 ['একদিন', 'পেছাল', 'আইপিএল']
# 38185 ['লড়াই', 'থামল', 'মাহমুদউল্লাহরও']
# 38186 ['অ্যালিস্টার', 'কুক', '‘স্যার’', 'উপাধি', 'পাচ্ছেন']
# 38187 ['কে', 'ফেভারিট', 'নিশ্চিত', 'নন', 'রোডস']
# 38188 ['চোখ', 'রাঙানো', 'গেইলকে', 'ফেরালেন', 'রুবেল']
# 38189 ['বেয়ারস্টো', 'বলেন..', '.']
# 38190 ['বল', 'টেম্পারিং', 'থামাতে', '‘প্যান্ট’', 'পরিবর্তনের', 'প্রস্তাব']
# 38191 ['স্যামুয়েলসকে', 'ফেরালেন', 'রুবেল']
# 38192 ['ঝলমলে', 'অভিষেকেও', 'আক্ষেপ', 'সাদমানের']
# 38193 ['দুই', '‘ম’র', 'মৌতাত']
# 38194 ['ঘরের', 'মাঠেই', 'সিরিজ', 'হারলো', 'অস্ট্রেলিয়া']
# 38195 ['সৌরভ', 'সভাপতি', 'হলে', 'বাংলাদেশ', 'বাড়তি', 'সুবিধা', 'পাবে', ':', 'জালাল', 'ইউনুস']
# 38196 ['এই', 'স্মিথকে', 'মেরে', 'থামাতাম', ':', 'শোয়েব', 'আখতার']
# 38197 ['ধর্মঘট', 'শেষে', 'জাতীয়', 'ক্রিকেট', 'লিগ', 'আজ', 'ফের', 'শুরু']
# 38198 ['সেই', '‘টেস্ট', 'ব্যাটসম্যান’', 'মুমিনুলের', 'ওয়ানডেতে', '১৮২']
# 38199 ['মুশফিক-লিটনের', 'পার্থক্য', 'ধরিয়ে', 'দিলেন', 'ডমিঙ্গো']
# 38200 ['আম্পায়ারকে', 'গালি', 'দিয়ে', 'নিষিদ্ধ', 'হলেন', 'নাসির']
# 38201 ['সাকিবের', 'তৃতীয়', 'শিকার', 'ক্রেমার']
# 38202 ['‘পারফর্ম', 'করলে', 'দরজা', 'খোলা', ',', 'নইলে', 'নয়’']
# 38203 ['সাকিব-মুস্তাফিজে', 'খুশি', 'হায়দরাবাদ-মুম্বাই']
# 38204 ['সাকিব', 'কাণ্ডে', 'সাবধান', 'বিসিবি']
# 38205 ['যে', 'খেলাটাকে', 'ভালোবাসি', ',', 'সেটিতে', 'নিষিদ্ধ', 'হওয়ায়', 'দুঃখিত', ':', 'সাকিব']
# 38206 ['জাতীয়', 'লিগে', 'ইমরুলের', 'ডাবল', 'সেঞ্চুরি']
# 38207 ['রিচার্ড', 'পাইবাসই', 'তামিম-সাকিবদের', 'কোচ', '!']
# 38208 ['ধোনি', 'হুইলচেয়ারে', 'চলাফেরা', 'করলেও', 'দলে', 'রাখতাম', ':', 'ডি', 'ভিলিয়ার্স']
# 38209 ['মুশফিকের', 'বিশ্বরেকর্ড']
# 38210 ['মোস্তাফিজকে', 'বসিয়েই', 'রাখা', 'হলো']
# 38211 ['ইন্দোর', 'টেস্ট', '', ':', 'বাংলাদেশ', '১৫০', 'আগরওয়াল', '২৪৩']
# 38212 ['বিপিএলে', 'সাকিবদের', 'হয়ে', 'খেলবেন', 'বিশ্বকাপজয়ী', 'মরগ্যান']
# 38213 ['ব্যাটিংয়ে', 'বাংলাদেশ']
# 38214 ['সিলেটে', 'টেস্ট', 'অভিষেক', ':', 'জয়', 'দিয়ে', 'রাঙাতে', 'চায়', 'বাংলাদেশ']
# 38215 ['আফগানদের', 'বিপক্ষে', '১২৩', 'রানে', 'অলআউট', 'বিসিবি', 'একাদশ']
# 38216 ['রোমাঞ্চকর', 'জয়ে', 'সমতায়', 'ফিরল', 'বাংলাদেশ']
# 38217 ['চিকিৎসকের', 'পরামর্শ', 'নিতে', 'বুধবার', 'ইংল্যান্ড', 'যাচ্ছেন', 'তামিম']
# 38218 ['রুপগঞ্জকে', 'হারিয়ে', 'দিলেন', 'লিজেন্ড', 'শাহরিয়ার']
# 38219 ['ধুঁকছে', 'বাংলাদেশ']
# 38220 ['মাশরাফি', 'ফিরে', 'এসে', 'খারাপ', 'করলে', 'মানুষ', 'নেগেটিভ', 'বলবে', ':', 'আশরাফুল']
# 38221 ['হারিস-বাবরের', 'সেঞ্চুরিতে', '৪১৮', 'রানে', 'ইনিংস', 'ঘোষণা', 'পাকিস্তানের']
# 38222 ['বোল্ড', 'হয়ে', 'ফিরলেন', 'মুশফিক']
# 38223 ['প্যান্টের', 'ঝড়ে', 'দিল্লির', 'সংগ্রহ', '১৭৪']
# 38224 ['বিবাহবার্ষিকীতে', 'দোয়া', 'চাইলেন', 'সাকিব']
# 38225 ['শ্বাসরুদ্ধকর', 'জয়ে', 'নিউজিল্যান্ডকে', 'অভিনন্দন', 'আফ্রিদির']
# 38226 ['উদ্বোধনী', 'ম্যাচে', 'টস', 'জিতে', 'ফিল্ডিংয়ে', 'চট্টগ্রাম']
# 38227 ['মোস্তাফিজের', 'বড়শিতে', '১২', 'কেজির', 'পাঙ্গাস', '(ভিডিও', ')']
# 38228 ['‘জয়ের', 'অভ্যাস’', 'নিয়ে', 'ফাইনাল', 'খেলতে', 'চায়', 'বাংলাদেশ']
# 38229 ['শ্রীলংকা', 'সফরে', 'বাংলাদেশ', 'অনূর্ধ্ব-১৯', 'দল']
# 38230 ['জাদেজা', 'আমাকে', 'খুঁজছিল', ':', 'মাঞ্জরেকার']
# 38231 ['টস', 'জিতে', 'ব্যাটিংয়ে', 'বাংলাদেশ']
# 38232 ['বাংলাদেশ', 'একাদশে', 'নেই', 'মোস্তাফিজ', ',', 'আছেন', 'মিঠুন']
# 38233 ['দশকের', "'", 'সবচেয়ে', 'বেশি', 'উইকেটশিকারি', ',', 'তবু', 'কেউ', 'মনে', 'রাখল', 'না', "'"]
# 38234 ['মোস্তাফিজের', 'মুম্বাই', 'অধ্যায়', 'হারে', 'শুরু']
# 38235 ['সব', 'রেকর্ড', 'নিজের', 'করে', 'নিলেন', 'রোহিত']
# 38236 ['অভিজ্ঞতা', 'বাজারে', 'কেনা', 'যায়', 'না', ',', 'ভারতের', 'হারের', 'পর', 'মনোজের', 'টুইট']
# 38237 ['দল', 'নিয়ে', 'সবাই', 'খুশি']
# 38238 ['ধোনির', 'ছয়গুলো', 'আসলে', 'এক', 'একটি', 'থাপ্পড়', '!']
# 38239 ['বাংলাদেশ-আফগানিস্তান', 'টেস্টে', 'অভিষেক', 'উইলসনের']
# 38240 ['উদ্বোধনী', 'জুটিতে', 'টাইগারদের', 'শুভ', 'সূচনা']
# 38241 ['ইনিংস', 'পরাজয়ে', 'সাকিবদের', 'নিয়ে', 'সোশ্যাল', 'মিডিয়ায়', 'ঝড়']
# 38242 ['সবার', 'আগে', 'ফাইনালে', 'কে', ',', 'ভারত', 'না', 'পাকিস্তান', '?']
# 38243 ['বাংলাদেশের', 'সেরা', 'ব্যাটসম্যান', 'মুশফিক', ':', 'হাবিবুল', 'বাশার']
# ...
# 42198 ['সেরেনার', 'ক্যারিয়ারের', 'লজ্জাজনক', 'পরাজয়']
# 42199 ['দ্বিতীয়', 'রাউন্ডে', 'নাদাল', 'সেরেনা']
# 42200 ['নতুন', 'রানী', 'পাচ্ছে', 'অস্ট্রেলিয়া', 'ওপেন']
# 42201 ['ইউএস', 'ওপেন', 'থেকে', 'দুই', 'নক্ষত্রের', 'বিদায়']
# 42202 ['টেনিসের', 'উজ্জ্বল', 'মুখ', '‘জোকার’']
# 42203 ['আবারও', 'ছিটকে', 'গেলেন', 'নাদাল']
# 42204 ['ক্রিকেট', 'খেলছেন', 'ফেদেরার', '?']
# 42205 ['ফের', 'সিংহাসনে', 'বসলেন', 'হালেপ']
# 42206 ['এক', 'রাতে', '২', 'নক্ষত্রের', 'পতন']
# 42207 ['কান্নায়', 'বিদায়', 'নাদালের']
# 42208 ['নাদালকে', 'সরিয়ে', 'রেকর্ড', 'গড়ে', 'শীর্ষে', 'ফেদেরার']
# 42209 ['লেভানডফস্কির', 'বায়ার্নের', 'মুখোমুখি', 'রোনাল্ডোর', 'রিয়াল']
# 42210 ['রোনাল্ডোকে', 'পেছনে', 'ফেলে', 'সেরা', 'ফেদেরার']
# 42211 ['ইতিহাস', 'ডাকছে']
# 42212 ['কাশ্মীরে', 'উত্তেজনায়', 'পাকিস্তান', 'সফর', 'বাতিল', 'করল', 'ভারত']
# 42213 ['ডোপ', 'টেস্টেও', 'বৈষম্যের', 'শিকার', 'সেরেনা']
# 42214 ['কাশ্মীর', 'ইস্যু:পাকিস্তান', 'সফর', 'বাতিল', 'ভারতের']
# 42215 ['নারী', 'ক্রীড়াবিদদের', 'মধ্যে', 'আয়ে', 'শীর্ষে', 'সেরেনা']
# 42216 ['খেলোয়াড়রা', 'যখন', 'প্রথম', 'ভোটার']
# 42217 ['নাদালের', 'অষ্টম', 'শিরোপা', 'জয়']
# 42218 ['মুস্তাফিজকে', 'পেছনে', 'ফেলবেন', 'রানা', '?']
# 42219 ['চেলসির', 'জয়', ',', 'ম্যানইউর', 'হার']
# 42220 ['রংহারা', 'রংপুর', ',', 'জয়ে', 'ফিরল', 'চট্টগ্রাম']
# 42221 ['৩৬৫', 'দিন', 'অপরাজিত', 'লিভারপুল']
# 42222 ['সৌম্যকে', 'হতাশ', 'করে', 'উড়ল', 'রাজশাহী']
# 42223 ['শেখ', 'রাসেলের', 'কষ্টার্জিত', 'জয়']
# 42224 ['তরুণদের', 'নিয়ে', 'এখনই', 'সিদ্ধান্ত', 'নয়', ':', 'নান্নু']
# 42225 ['নতুন', 'বছরে', 'কঠিন', 'চ্যালেঞ্জ']
# 42226 ['আর্জেন্টিনা-চিলির', 'লড়াইয়ে', 'শুরু', 'হবে', 'কোপা', 'আমেরিকা']
# 42227 ['প্রতি', 'বছর', 'তিন', 'মোড়লের', 'টুর্নামেন্ট', '!']
# 42228 ['ওয়াহাবকে', 'হারাল', 'মাশরাফিরা']
# 42229 ['উদ্বোধনী', 'টিকিটের', 'হাহাকার']
# 42230 ['ফিরে', 'যাচ্ছেন', 'পেস', 'বোলিং', 'কোচ', 'ল্যাঙ্গেভেল্ট']
# 42231 ['সুপার', 'সিরিজের', 'সমালোচনায়', 'ডু', 'পেস্নসিস']
# 42232 ['নয়জন', 'বোলার', 'ব্যবহারে', 'রাসেলের', 'ব্যাখ্যা']
# 42233 ['মালান', 'ঝড়ে', 'নাটকীয়', 'জয়', 'কুমিল্লার']
# 42234 ['সিলেটকে', 'গুঁড়িয়ে', 'রাজশাহীর', 'জয়']
# 42235 ['সব', 'খেলায়', 'নিষিদ্ধ', 'রাশিয়া', '!']
# 42236 ['অস্ট্রেলিয়ান', 'ওপেনে', 'তারকার', 'মেলা']
# 42237 ['স্বর্ণকন্যা', 'প্রিয়া', 'শঙ্কামুক্ত']
# 42238 ['সংবাদ', 'সংক্ষেপ']
# 42239 ['অপরাজিত', 'থেকে', 'নকআউটে', 'জুভেন্টাস']
# 42240 ['দুই', 'হাজারি', 'ক্লাবে', 'প্রথম', 'তামিম']
# 42241 ['শেন', 'ওয়ার্নের', 'অন্য', 'স্বপ্ন']
# 42242 ['শূন্য', 'রানে', 'অঞ্জলির', '৬', 'উইকেট']
# 42243 ['জানুয়ারিতে', 'নারী', 'ফুটবল', 'লিগ']
# 42244 ['ভালোই', 'কাটল', 'নাদাল', 'জোকোভিচের']
# 42245 ['ক্রীড়াবিশ্ব', 'মেতে', 'উঠবে', 'অলিম্পিকের', 'উৎসবে']
# 42246 ['পুলিশকে', 'নিয়ে', 'শেষ', 'আটে', 'আবাহনী']
# 42247 ['টিভিতে', 'আজ']
# 42248 ['মেসি', 'জাদুতে', 'ফের', 'শীর্ষে', 'বার্সা']
# 42249 ['জানুয়ারিতে', 'ভারতের', 'ঠাঁসা', 'ক্রীড়াসূচি']
# 42250 ['লিভারপুলের', 'জালে', 'অ্যাস্টনভিলার', '৫', 'গোল', '!']
# 42251 ['২০টি', 'গ্র্যান্ড', 'স্স্নাম', 'জয়ের', 'স্বপ্ন', 'নাদালের']
# 42252 ['টিভিতে', 'আজ']
# 42253 ['রশিদকে', 'সরিয়ে', 'নেতৃত্ব্বে', 'আসগর']
# 42254 ['টিভিতে', 'আজ']
# 42255 ['বিসিবির', 'সিদ্ধান্তে', 'হতাশ', 'মিসবাহ']
# 42256 ['ইংল্যান্ড', 'সিরিজই', 'শেষ', 'ফিল্যান্ডারের']
# 42257 ['জেসুসের', 'নৈপুণ্যে', 'ম্যানসিটির', 'দাপুটে', 'জয়']
# 42258 ['ইউরোর', 'আগেই', 'রিয়ালে', 'পগবা', '!']
# 42259 ['লিগ', 'কাপের', 'সেমিতে', 'ম্যানইউ-ম্যানসিটি']
# 42260 ['সংবাদ', 'সংক্ষেপ']
# 42261 ['রুটের', 'রেকর্ড', 'গড়া', 'ডাবল', 'সেঞ্চুরি']
# 42262 ['বড়', 'জয়ে', 'বছর', 'শেষ', 'বার্সা-পিএসজির']
# 42263 ['বিপিএলে', 'উদ্বোধনী', 'অনুষ্ঠানে', 'চমক']
# 42264 ['বঙ্গবন্ধু', 'গোল্ডকাপে', 'কঠিন', 'গ্রম্নপে', 'বাংলাদেশ']
# 42265 ['পাঁচ', 'মাস', 'পর', 'মাঠের', 'লড়াইয়ে', 'মাশরাফি']
# 42266 ['শেষ', 'আটের', 'পথে', 'মুক্তিযোদ্ধা']
# 42267 ['জুভেন্টাস-বায়ার্নের', 'দারুণ', 'জয়']
# 42268 ['বিস্মিত', 'রংপুরের', 'বিদেশি', 'কোচ']
# 42269 ['রিয়ালের', 'প্রতিপক্ষ', 'ম্যানসিটি', ',', 'নাপোলির', 'মুখোমুখি', 'বার্সা']
# 42270 ['চেলসির', 'হার', ',', 'বায়ার্নের', 'দাপুটে', 'জয়']
# 42271 ['ঢাকাকে', 'জেতালেন', 'মেহেদী']
# 42272 ['টিভিতে', 'আজ']
# 42273 ['বিসিবিকে', 'ধন্যবাদ', 'প্রোটিয়া', 'বোর্ডের']
# 42274 ['বদলে', 'গেল', 'রংপুরের', 'পরিচালক']
# 42275 ['সেরা', 'চারের', 'আশায়', 'বছর', 'শেষ', 'ম্যানইউর']
# 42276 ['টিভিতে', 'আজ']
# 42277 ['মাশরাফি', 'অনুপ্রেরণার', 'নাম', ':', 'শেহজাদ']
# 42278 ['মুস্তাফিজকে', 'নিয়ে', 'চিন্তিত', 'বিসিবি']
# 42279 ['বিপিএলের', 'উদ্বোধনী', 'ম্যাচে', 'দর্শকখরা']
# 42280 ['হাই-জাম্পে', 'রুপা', 'জিতলেন', 'মাহফুজ']
# 42281 ['ভারতের', 'ফুচকাওয়ালা', 'বিশ্বকাপ', 'ক্রিকেটে']
# 42282 ['তলানি', 'থেকেই', 'লড়তে', 'হবে', 'জামালদের']
# 42283 ['অধরা', 'জয়ের', 'স্বাদ', 'পেল', 'সিলেট']
# 42284 ['টিভিতে', 'আজ']
# 42285 ['আরামবাগকে', 'হারিয়ে', 'পুলিশের', 'চমক']
# 42286 ['ভারতের', 'বাইরেও', 'হবে', 'আইপিএলের', 'ম্যাচ']
# 42287 ['টিভিতে', 'আজ']
# 42288 ['সৌরভের', 'দিকে', 'তাকিয়ে', 'রশিদ']
# 42289 ['এমবাপের', 'প্রশংসায়', 'পঞ্চমুখ', 'ইব্রাহিমোভিচ']
# 42290 ['জয়ে', 'বছর', 'শুরু', 'ম্যানসিটি-আর্সেনালের']
# 42291 ['বিপিএলে', 'খেলবেন', 'নিষিদ্ধ', 'ক্রিকেটার', '!']
# 42292 ['ক্লাব', 'বিশ্বকাপে', 'লিভারপুল', 'চ্যাম্পিয়ন']
# 42293 ['মিথ্যা', 'বলে', 'শাস্তির', 'মুখে', 'দুই', 'ভারতীয়', 'ক্রিকেটার']
# 42294 ['ক্রিকেটে', 'আরেকটি', 'সোনা', 'জয়', 'বাংলাদেশের']
# 42295 ['খেতাব', 'জিতে', 'উচ্ছ্বসিত', 'রোনালদো']
# 42296 ['মেসির', 'হ্যাটট্রিকে', 'শীর্ষে', 'বার্সা']
# 42297 ['টিভিতে', 'আজ']
# 42298 ['বর্ষসেরার', 'সংক্ষিপ্ত', 'তালিকায়', 'রোমান']
# 42299 ['ইংল্যান্ডের', 'টেস্ট', 'দলে', 'অ্যান্ডারসন-বেয়ারস্টো-উড']
# 42300 ['আবাহনীর', 'শ্রেষ্ঠত্ব', 'ধরে', 'রাখার', 'চ্যালেঞ্জ']
# 42301 ['বেতন', 'দেওয়ায়', 'শীর্ষে', 'বার্সেলোনা']
# 42302 ['বাংলাদেশের', 'প্রথম', 'নারী', 'ফিফা', 'রেফারি', 'জয়া']
# 42303 ['টিভিতে', 'আজ']
# 42304 ['সংবাদ', 'সংক্ষেপ']
# 42305 ['মাইলস্টোন', 'স্কুল', 'অ্যান্ড', 'কলেজের', 'পুরস্কার', 'বিতরণী']
# 42306 ['লিভারপুলের', 'জয়', ',', 'ম্যানসিটির', 'হার']
# 42307 ['কোচ', 'ছাড়াই', 'ভারতে', 'অজিরা']
# 42308 ['সিরিজ', 'শুরুর', 'আগে', 'প্রোটিয়া', 'দলে', 'ধাক্কা']
# 42309 ['সমালোচনায়', 'ক্ষতবিক্ষত', 'নেইমার']
# 42310 ['বাংলাদেশের', 'প্রথম', 'পদক', 'অন্তরার']
# 42311 ['প্রথম', 'জয়ে', 'বেঁচে', 'থাকল', 'আশা']
# 42312 ['সংবাদ', 'সংক্ষপে']
# 42313 ['মেসিকে', 'নতুন', 'চুক্তির', 'প্রস্তাব', 'বার্সার']
# 42314 ['বিজয়', 'দিবস', 'হকি', 'শুরু', 'আজ']
# 42315 ['আধুনিক', 'সুইমিং', 'কমপেস্নক্সের', 'উদ্বোধন']
# 42316 ['ক্যাসিনোকান্ডে', 'ক্রীড়াঙ্গন', 'ছিল', 'উত্তাল']
# 42317 ['বিবর্ণ', 'মুস্তাফিজ', 'ওয়ানডের', 'চতুর্থ', 'সেরা', 'উইকেট', 'শিকারি']
# 42318 ['টি২০', 'সিরিজ', 'ভারতের']
# 42319 ['মুজিবকে', 'সামলাতে', 'ব্যাটিং', 'প্রমোশন', '!']
# 42320 ['মেসি', 'সময়ের', 'সেরা', 'সর্বকালের', 'নয়', ':', 'রোনালদিনহো']
# 42321 ['বিগ', "'", 'ব্যাশের', 'চেয়েও', 'আকর্ষণীয়', 'বিপিএল', "'"]
# 42322 ['মানের', 'চতুর্থ', 'হওয়া', 'লজ্জার', '', ':', 'মেসি']
# 42323 ['ইমরুলের', 'ব্যাটে', 'চট্টগ্রামের', 'উড়ন্ত', 'সূচনা']
# 42324 ['পুলিশের', 'বিপক্ষে', 'বিকেএসপির', 'গোল', 'উৎসব']
# 42325 ['ফুটবল', 'উন্নয়নে', 'পরামর্শ', 'জেমির']
# 42326 ['সংবাদ', 'সংক্ষপে']
# 42327 ['ইনিংস', 'ব্যবধানেই', 'হারল', 'পাকিস্তান']
# 42328 ['বার্সেলোনার', 'বিরুদ্ধে', 'আবারও', 'নেইমারের', 'মামলা']
# 42329 ['গার্দিওলাকে', 'বিপদে', 'ফেললেন', 'আর্তেতা', '?']
# 42330 ['টিভিতে', 'আজ']
# 42331 ['টানা', 'হারের', 'কারণ', 'খুঁজছে', 'রংপুর']
# 42332 ['কাতারে', 'যুক্তরাষ্ট্রের', 'ফুটবল', 'ক্যাম্প', 'স্থগিত']
# 42333 ['টিভিতে', 'আজ']
# 42334 ['স্বর্ণজয়ী', 'সীমান্তর', 'স্বপ্ন', 'অলিম্পিক', '!']
# 42335 ['সংবাদ', 'সংক্ষপে']
# 42336 ['অসুস্থতার', 'হিড়িক', 'ইংল্যান্ড', 'দলে']
# 42337 ['ক্রিকেটকে', 'বিদায়', 'বললেন', 'সিডল']
# 42338 ['মাশরাফির', 'ঢাকায়', 'জ্বরের', 'হানা']
# 42339 ['প্রতিরোধ', 'ভেঙে', 'সিরিজ', 'অস্ট্রেলিয়ার']
# 42340 ['মুস্তাফিজকে', 'টপকে', 'ফের', 'শীর্ষে', 'রানা']
# 42341 ['নিজের', 'ব্যর্থতা', 'মানছেন', 'তাসকিন']
# 42342 ['টাইব্রেকারে', '৩৭', 'শটের', 'অবিশ্বাস্য', 'ম্যাচ', 'দেখল', 'সিলেট', '!']
# 42343 ['সংবাদ', 'সংক্ষেপ']
# 42344 ['ক্যারিয়ারে', 'এটাই', 'সেরা', 'বছর', ':', 'রোমান']
# 42345 ['জাজাইয়ের', 'ফিফটিতে', 'বিধ্বস্ত', 'ঢাকা']
# 42346 ['বিসিবি', 'চাইলে', 'পাকিস্তান', 'সফরে', 'যেতে', 'আপত্তি', 'নেই', 'ডমিঙ্গোর']
# 42347 ['তৃতীয়', 'এইচআরসি', 'গলফ', 'কাপ', 'টুর্নামেন্টের', 'উদ্বোধন']
# 42348 ['চিন্তাভাবনার', 'ধরন', 'বদলে', 'অন্য', 'রকম', 'তাসকিন']
# 42349 ['মাশরাফি', 'বিন', 'মর্তুজার', 'উদারতা']
# 42350 ['গোলাপি', 'বলের', 'টেস্টে', 'বাংলাদেশকে', 'চায়', 'পাকিস্তান']
# 42351 ['ফাইনালে', 'বাংলাদেশের', 'মেয়েরা']
# 42352 ['দুর্দান্ত', 'দল', 'পেয়ে', 'সন্তুষ্ট', 'রাজশাহী', 'কোচ']
# 42353 ['টেকনিক-বেসিক', 'কিছু', 'না', 'পারফর্ম', 'করলে', 'সব', 'ঠিক']
# 42354 ['রোহিতের', 'ওপরে', 'শুধুই', 'শচিন', 'টেন্ডুলকার']
# 42355 ['বসুন্ধরাকে', 'হারিয়ে', 'গ্রম্নপ', 'চ্যাম্পিয়ন', 'চট্টলা']
# 42356 ['টানা', 'তৃতীয়', 'হার', 'রংপুরের']
# 42357 ['গেলেন', 'আফ্রিদী', 'আসছেন', 'আমলা-শেহজাদ']
# 42358 ['দলের', 'ওপর', 'আস্থা', 'নেই', 'মিঠুনের', '!']
# 42359 ['লিভারপুল', 'আর', 'মেসির', 'বছর']
# 42360 ['সংবাদ', 'সংক্ষেপ']
# 42361 ['ভারত-উইন্ডিজ', 'অঘোষিত', 'ফাইনাল', 'আজ']
# 42362 ['লিভারপুলকে', 'হুমকি', 'জিদানের']
# 42363 ['এসএ', 'গেমসের', 'পর্দা', 'উঠছে', 'আজ']
# 42364 ['যেসব', 'রেকর্ডের', 'সামনে', 'মেসি']
# 42365 ['আর্সেনালের', 'দুর্দশা', 'অব্যাহত']
# 42366 ['নতুন', 'রেকর্ড', 'লেস্টারের']
# 42367 ['টিভিতে', 'আজ']
# 42368 ['টিভিতে', 'আজ']
# 42369 ['সংবাদ', 'সংক্ষপে']
# 42370 ['রুদ্ধশ্বাস', 'ফাইনালে', 'মেয়েদের', 'সোনা', 'জয়']
# 42371 ['পাকিস্তানিদের', 'এশিয়া', 'একাদশে', 'চায়', 'না', 'ভারত']
# 42372 ['টিভিতে', 'আজ']
# 42373 ['নৌবাহিনী', 'ও', 'সোনালী', 'ব্যাংকের', 'জয়']
# 42374 ['চট্টগ্রাম', 'পর্ব', 'শেষ', 'মাহমুদউলস্নাহর']
# 42375 ['বিপিএলের', 'চট্টগ্রাম', 'পর্ব', 'শুরু', 'আজ']
# 42376 ['প্রতি', 'ছক্কায়', '২৫০', 'ডলার']
# 42377 ['টিভিতে', 'আজ']
# 42378 ['ফাইনালে', 'লিভারপুল']
# 42379 ['রেকর্ড', '৩৫', 'ম্যাচে', 'অপরাজিত', 'লিভারপুল']
# 42380 ['লিটন-আফিফদের', 'ধারাবাহিকতা', 'চান', 'ইংলিশ', 'কোচ']
# 42381 ['ড্রেসিংরুমে', 'ফিরে', 'জানলেন', 'তিনি', 'আউট', 'নন', '!']
# 42382 ['ভুটানের', 'কাছে', 'হারে', 'শুরু', 'বাংলাদেশের']
# 42383 ['টিভিতে', 'আজ']
# 42384 ['পিএসএলে', 'দল', 'পেলেন', 'না', 'বাংলাদেশের', 'কেউই']
# 42385 ['ইতালিয়ান', 'সুপার', 'কাপ', 'চ্যাম্পিয়ন', 'লাজিও']
# 42386 ['নিরুত্তাপ', 'ম্যাচে', 'মুস্তাফিজ', 'ঝলক']
# 42387 ['একে', 'অন্যকে', 'ছাড়িয়ে', 'যাওয়ার', 'লড়াই']
# 42388 ['বিজয়', 'দিবসে', 'ক্রিকেটারদের', 'মিলনমেলা']
# 42389 ['ক্রিকেট', 'মাঠে', 'সাপের', 'উৎপাত']
# 42390 ['ধাওয়ানের', 'পর', 'দলে', 'নেই', 'ভুবনেশ্বর']
# 42391 ['সংবাদ', 'সংক্ষপে']
# 42392 ['সংবাদ', 'সংক্ষেপ']
# 42393 ['ব্যাটিংটা', 'উপভোগ', 'করছেন', 'মেহেদী']
# 42394 ['গ্রম্নপ', 'চ্যাম্পিয়ন', 'ম্যানইউ-আর্সেনাল']
# 42395 ['ম্যানসিটির', 'শিরোপার', 'আশা', 'শেষ']
# 42396 ['সোনার', 'মঞ্চে', 'যেতে', 'কঠিন', 'সমীকরণ']
# 42397 ['লেবুশেনের', 'সেঞ্চুরিতে', 'অস্ট্রেলিয়ার', 'দিন']
# 42398 ['আইপিএল', 'নিয়ে', 'মাথাব্যথা', 'নেই', 'মুশফিকের']
# 42399 ['অবিশ্বাস্য', 'কোহলিতে', 'দুর্দান্ত', 'ভারত']
# 42400 ['ঢাকাকেই', 'এগিয়ে', 'রাখলেন', 'বিজয়']
# 42401 ['পাকিস্তানের', 'বিপক্ষে', 'প্রতিশোধের', 'ম্যাচ']
# 42402 ['মোহামেডান', 'সমর্থক', 'দলের', 'নতুন', 'কমিটি', 'ঘোষণা']
# 42403 ['ক্রিকেটাররা', 'ভাষা', 'বোঝেন', 'না', ':', 'গিবস']
# 42404 ['ম্যানসিটির', 'জয়', ',', 'আর্সেনালের', 'ড্র']
# 42405 ['বাংলাদেশি', 'ছাড়াই', 'মার্চে', 'শুরু', 'আইপিএল', '!']
# 42406 ['ফের', 'পেছাল', 'বিপিএল', 'ফুটবল']
# 42407 ['এক', 'সপ্তাহের', 'সফরে', 'পাকিস্তান', 'যাবে', 'টাইগাররা', '!']
# 42408 ['হ্যামিল্টন', 'টেস্টেও', 'চাপে', 'ইংল্যান্ড']
# 42409 ['ফুটবলে', 'সাফল্য-ব্যর্থতায়', 'মোড়ানো', 'বছর']
# 42410 ['খুলনার', 'হ্যাটট্রিক', 'জয়']
# 42411 ['টিভিতে', 'আজ']
# 42412 ['সংবাদ', 'সংক্ষেপ']
# 42413 ['সংবাদ', 'সংক্ষেপ']
# 42414 ['মুশফিক', 'বীরত্বে', 'খুলনার', 'জয়']
# 42415 ['চমক', 'দেখানো', 'পুলিশের', 'বিদায়']
# 42416 ['সংবাদ', 'সংক্ষেপ']
# 42417 ['ক্রিকেটার', 'থেকে', 'গায়ক', 'সিকান্দার', 'রাজা']
# 42418 ['ভারতের', 'বিপক্ষে', 'দুটি', 'দিবা-রাত্রির', 'টেস্ট', 'চায়', 'অস্ট্রেলিয়া', '!']
# 42419 ['তামিম-মেহেদীর', 'ফিফটিতে', 'উড়ে', 'গেল', 'সিলেট']
# 42420 ['কোহলি', 'ক্রিকেটের', 'রোনালদো', ':', 'লারা']
# 42421 ['ম্যানসিটির', 'ক্রিসমাস', 'পার্টি', 'বাতিল', '!']
# 42422 ['বঙ্গবন্ধু', 'আন্তর্জাতিক', 'গ্র্যান্ড', 'মাস্টার', 'দাবা']
# 42423 ['ইমরুলের', 'ব্যাটে', 'পেস্ন', 'অফে', 'চট্টগ্রাম']
# 42424 ['আবিদ', 'আলির', 'আরও', 'এক', 'কীর্তি']
# 42425 ['সংবাদ', 'সংক্ষেপ']
# 42426 ['বাফুফেকে', 'ফিফার', 'জরিমানা']
# 42427 ['সংবাদ', 'সংক্ষেপ']
# 42428 ['ঘরের', 'মাঠে', 'সিরিজ', 'জিতল', 'পাকিস্তান']
# 42429 ['চট্টগ্রাম', 'পর্বে', 'দু্যতি', 'ছড়ানো', 'তরুণরা']
# 42430 ['টিভিতে', 'আজ']
# 42431 ['বোলিং', 'কোচ', 'হতে', 'আগ্রহী', 'সুজন']
# 42432 ['সোনালি', 'সাফল্যে', 'খুশি', 'আফিফরা']
# 42433 ['লিভারপুলের', 'জয়', ',', 'টটেনহামের', 'হার']
# 42434 ['স্মিথের', 'ব্যাটে', 'অস্ট্রেলিয়ার', 'দিন']
# 42435 ['টিভিতে', 'আজ']
# 42436 ['রোনালদোর', 'গোলে', 'জুভেন্টাসের', 'বড়', 'জয়']
# 42437 ['রিয়াল-পিএসজির', 'দাপুটে', 'জয়']
# 42438 ['বিপিএল', 'এবার', 'বন্দরনগরীতে']
# 42439 ['রংপুর', 'রেঞ্জার্সের', 'অধিনায়ক', 'নবি']
# 42440 ['আফ্রিদির', 'শূন্যের', 'সেঞ্চুরি']
# 42441 ['শ্রীলংকাকে', 'সহজে', 'হারিয়ে', 'বাংলাদেশের', 'শুরু']
# 42442 ['দল', 'বেশি', 'হওয়ায়', 'খুশি', 'দুই', 'ক্লাব']
# 42443 ['ছুটি', 'শেষে', 'অনুশীলনে', 'লিওনেল', 'মেসি']
# 42444 ['খুলনাকে', 'হারিয়ে', 'শীর্ষে', 'ঢাকা']
# 42445 ['পিএসজিকে', 'জেতালেন', 'এমবাপে-নেইমার']
# 42446 ['খুলনার', 'নেতৃত্বে', 'মুশফিক', '!']
# 42447 ['টিভিতে', 'আজ']
# 42448 ['এক', 'ফুটবলারের', 'পিছে', '৪০', 'ক্লাব', '!']
# 42449 ['হ্যামিল্টন', 'টেস্ট', 'ড্র', ',', 'সিরিজ', 'কিউইদের']
# 42450 ['ফুটবলে', 'সোনার', 'লড়াই', 'থেকে', 'ছিটকে', 'গেল', 'বাংলাদেশ']
# 42451 ['মোহামেডানের', 'সামনে', 'নির্ভার', 'রহমতগঞ্জ']
# 42452 ['এগারোজনে', 'করল', 'মাত্র', 'এক', 'রান', '!']
# 42453 ['অস্ট্রেলিয়া-শ্রীলংকা', 'সিরিজে', 'সেরা', 'দল', 'ভারতের']
# 42454 ['আরামবাগের', 'সামনে', 'চ্যাম্পিয়ন', 'আবাহনী']
# 42455 ['বাংলাদেশ', 'ফাইনাল', 'খেলার', 'মতো', 'দল', '', ':', 'আকবর']
# 42456 ['রংপুর', 'রেঞ্জার্সে', 'ওয়াটসন']
# 42457 ['পাকিস্তান', 'সফরে', 'ছাড়পত্র', 'পাচ্ছে', 'বিসিবি']
# 42458 ['নক', 'আউটে', '৩৭', 'ব্রাজিলিয়ান', '!']
# 42459 ['বিপিএল', 'অভিজ্ঞতা', 'নিয়ে', 'মুখিয়ে', 'আমলা']
# 42460 ['ওয়ার্নারের', 'ট্রিপলে', 'বিপাকে', 'পাকিস্তান']
# 42461 ['বিপিএলের', 'টাইটেল', 'স্পন্সর', 'আকাশ']
# 42462 ['সিদ্দিকুরের', 'হাত', 'ধরে', 'এগোচ্ছে', 'গলফ']
# 42463 ['সংবাদ', 'সংক্ষেপ']
# 42464 ['টিভিতে', 'আজ']
# 42465 ['সংবাদ', 'সংক্ষপে']
# 42466 ['ঢাকায়', 'আসছেন', 'ম্যারাডোনা', '!']
# 42467 ['ভিন্ন', 'গ্রম্নপে', 'আবাহনী-বসুন্ধরা']
# 42468 ['বড়', 'ব্যবধানের', 'জয়', 'চাই', 'বাংলাদেশের']
# 42469 ['ইতালিয়ান', 'লিগের', 'বর্ষসেরা', 'রোনালদো']
# 42470 ['সৌম্য', 'ঝড়ে', 'উড়ে', 'গেল', 'ভুটান']
# 42471 ['কনসার্ট', 'মাতাতে', 'আসছেন', 'তারা']
# 42472 ['মেসির', 'জন্য', 'আলাদা', 'ব্যালন', "ডি'অর", 'চান', 'নেইমার']
# 42473 ['তৃতীয়', 'এইচআরসি', 'গলফ', 'কাপ', 'টুর্নামেন্টের', 'উদ্বোধন', 'আজ']
# 42474 ['তৃতীয়', 'এইচআরসি', 'গলফ', 'কাপ', 'টুর্নামেন্ট', 'সমাপ্ত']
# 42475 ['বছরের', 'শুরুতে', 'বিশ্রামে', 'হোল্ডার']
# 42476 ['টিভিতে', 'আজ']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 42477
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b11b3f703070> in <cell line: 3>()
#       2 tokenizer = Tokenizer()
#       3 for i in range(len(pre_data.headline)):
# ----> 4   dt=pre_data.headline[i]
#       5   token=tokenizer.word_tokenizer(dt)
#       6   print(i,token)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 42477

# %%
pre_data = data_set.dropna()
pre_data.isnull().sum()
# Out:
# headline          0
# category          0
# newspaper name    0
# dtype: int64

# %%
from bltk.langtools import remove_stopwords
from bltk.langtools import Tokenizer

tokenizer = Tokenizer()
dt='আমার নামে হল তোমার নাম।'
token=tokenizer.word_tokenizer(dt)
st = remove_stopwords(token,level='soft')
print(st)
# Out:
# ['নামে', 'হল', 'তোমার', 'নাম']

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
